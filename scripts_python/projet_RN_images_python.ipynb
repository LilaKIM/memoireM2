# %%
# !pip install pandas_ml
# !pip install scikit-learn==0.21
# !pip install pandas==0.24.2
# Out:
# Requirement already satisfied: pandas_ml in /usr/local/lib/python3.7/dist-packages (0.6.1)
# Requirement already satisfied: pandas>=0.19.0 in /usr/local/lib/python3.7/dist-packages (from pandas_ml) (0.24.2)
# Requirement already satisfied: enum34 in /usr/local/lib/python3.7/dist-packages (from pandas_ml) (1.1.10)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.0->pandas_ml) (2.8.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.0->pandas_ml) (1.19.5)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.0->pandas_ml) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.5.0->pandas>=0.19.0->pandas_ml) (1.15.0)
# Requirement already satisfied: scikit-learn==0.21 in /usr/local/lib/python3.7/dist-packages (0.21.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.21) (1.19.5)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.21) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.21) (1.0.1)
# Requirement already satisfied: pandas==0.24.2 in /usr/local/lib/python3.7/dist-packages (0.24.2)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from pandas==0.24.2) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from pandas==0.24.2) (2.8.1)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.7/dist-packages (from pandas==0.24.2) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.5.0->pandas==0.24.2) (1.15.0)

# %%
import keras
import cv2
import re
import os
import numpy as np
import matplotlib.pyplot as plt
import glob as glb
import pandas as pd
import tensorflow as tf
from __future__ import print_function
from sklearn.metrics import classification_report
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.utils import np_utils
from keras.utils import to_categorical
from pandas_ml import ConfusionMatrix
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adadelta
from keras import optimizers
from google.colab  import files, drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def getCSV(resultat, path_output):
  """
  input : dict(result), str(path to csv)
  output : obj(df)
  """
  df = pd.DataFrame.from_dict(resultat, orient="index")
  # print(df)
  return df.to_csv(path_output, sep="\t", encoding="utf8")

# %% [markdown]
# ## Ecriture des résultats

# %% [markdown]
# ### Utilisation d'un dictionnaire avant de le transformer en dataframe

# %%
def getScoreLocuteur(report):
  """
  input : str(classification report)
  output : dict(scores)
  """
  lignes = report.split("\n")
  score = {}
  for n in range(1, len(lignes)):
    # print(lignes[n])
    if lignes[n] != "":
      lignes[n] = lignes[n].strip()
      if 'avg' in lignes[n]: lignes[n] = re.sub(" avg", "_avg",lignes[n])
      data = lignes[n].split()
      if data[0] != "accuracy":
        # print(data)
        score["precision_"+data[0]] = data[1]
        score["recall_"+data[0]] = data[2]
        score["f1_score_"+data[0]] = data[3]
        score["support_"+data[0]] = data[4]
      else:
        score["f1_score_"+data[0]] = data[1]
        score["support_"+data[0]] = data[2]

  return score

# %% [markdown]
# ### Initiation d'une liste pour sauvegarder les identifiants des locuteurs

# %%
def getListLocuteur(path_to_files):
  """
  input : str(path to files)
  output : list(list of speakers)
  """
  locs = list()
  for path in glb.glob(path_to_files):
    loc_file = "_".join(path.split('/')[-1].split('_')[0:6])
    if loc_file not in locs:
      locs.append(loc_file)
  return locs

# %%
def getListSegment(path_to_files):
  """
  input : str(path to files)
  output : list(list of segments)
  """
  segments = list()
  for path in glb.glob(path_to_files):
    segment = path.split('/')[-1].split('_')[6]
    if segment not in segments:
      segments.append(segment)
  return segments

# %% [markdown]
# ### Récupérations et transformations des données : les données à prédire

# %%
def getTestSetLocuteur(locuteur, path_input, img_rows=28, img_cols=28, num_classes=2):
  """
  input : str(id_locuteur), str(path to test files), int(image_rows), int(image_cols), int(number-classes)
  output : list(images), list(label)
  """
  x_test_loc = []
  y_test_loc = []
  for path in glb.glob(path_input):
  #print(path)
    fileName = path.split('/')[-1]
  #print(fileName)
  #print(fileName.split('_'))
    if locuteur in fileName: 
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_test_loc.append(x)
      y_test_loc.append(y)

  #print(len(x_test_loc))
  x_test_loc = np.array(x_test_loc)
  x_test_loc = x_test_loc.reshape(-1, x_test_loc.shape[1],x_test_loc.shape[2],1)
  x_test_loc = x_test_loc.astype('float32')
  x_test_loc /= 255. 

  y_test_loc = np.array(y_test_loc)
  y_test_loc = to_categorical(y_test_loc, num_classes, dtype='float32')
  return x_test_loc, y_test_loc

# %%
def getTestSetSegment(segment, path_input, img_rows=28, img_cols=28, num_classes=2):
  """
  input : str(segment), str(path to test files), int(image_rows), int(image_cols), int(number-classes)
  output : list(images), list(label)
  """
  x_test_seg = []
  y_test_seg = []
  for path in glb.glob(path_input):
  #print(path)
    fileName = path.split('/')[-1]
  #print(fileName)
  #print(fileName.split('_'))
    if segment in fileName.split('_')[6]: 
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_test_seg.append(x)
      y_test_seg.append(y)

  #print(len(x_test_loc))
  x_test_seg = np.array(x_test_seg)
  x_test_seg = x_test_seg.reshape(-1, x_test_seg.shape[1],x_test_seg.shape[2],1)
  x_test_seg = x_test_seg.astype('float32')
  x_test_seg /= 255. 

  y_test_seg = np.array(y_test_seg)
  y_test_seg = to_categorical(y_test_seg, num_classes, dtype='float32')
  return x_test_seg, y_test_seg

# %% [markdown]
# ## Initiation de la prédiction d'un modèle

# %%
def testLocuteur(model, path_output="drive/Shareddrives/ReseauNeurones/resume_resultats/all_score_loc.csv", path_input="drive/Shareddrives/ReseauNeurones/images/test/*/*"):
  """
  input : str(chemin vers les fichiers de test), str(chemin pour sauvegarder le fichier csv)
  output : df[col : scores, line : locuteur]
  """
  resultat = dict()
  locs = getListLocuteur(path_input)

  for locuteur in locs:
    x_test_loc, y_test_loc = getTestSetLocuteur(locuteur, path_input)
    Y_test = np.argmax(y_test_loc, axis=1) # Convert one-hot to index
    y_pred = model.predict_classes(x_test_loc)
    resultat[locuteur] = getScoreLocuteur(classification_report(Y_test, y_pred))

  return getCSV(resultat, path_output)

# %%
def testSegment(model, path_output="drive/Shareddrives/ReseauNeurones/resume_resultats/all_score_loc.csv", path_input="drive/Shareddrives/ReseauNeurones/images/test/*/*"):
  """
  input : str(chemin vers les fichiers de test), str(chemin pour sauvegarder le fichier csv)
  output : df[col : scores, line : locuteur]
  """
  resultat = dict()
  segments = getListSegment(path_input)

  for seg in segments:
    x_test_loc, y_test_loc = getTestSetSegment(seg, path_input)
    Y_test = np.argmax(y_test_loc, axis=1) # Convert one-hot to index
    y_pred = model.predict_classes(x_test_loc)
    resultat[seg] = getScoreLocuteur(classification_report(Y_test, y_pred))

  return getCSV(resultat, path_output)

# %% [markdown]
# ## Récupérations et transformations des données pour construire un modèle

# %%
def getDataSet(path_input, img_rows=28, img_cols=28, num_classes=2):
  """
  input : str(id_locuteur), str(path to test files), int(image_rows), int(image_cols), int(number-classes)
  output : list(images), list(label)
  """
  x_data = []
  y_data = []
  fileNames = []
  
  for path in glb.glob(path_input) :
    label = path.split('/')[-2] #nasalité
    x = cv2.imread(path, 0).astype(np.uint8) 
    x = cv2.resize(x, (img_rows, img_cols)) 
    y = dicoLocs[label]
    x_data.append(x) 
    y_data.append(y)
    fileNames.append(path.split('/')[-1])

  x_data = np.array(x_data)
  x_data = x_data.reshape(-1, x_data.shape[1],x_data.shape[2],1)
  x_data = x_data.astype('float32')
  x_data /= 255. 

  y_data = np.array(y_data)
  y_data = to_categorical(y_data, num_classes, dtype='float32')
  
  return x_data, y_data, fileNames

# %% [markdown]
# ## Construction du classifieur

# %%
def keras_RN(x_train, y_train, x_test, y_test, activation, loss, optimizer, num_classes=2, batch_size=10, epochs=115, verbose=1):
  model = Sequential()
  model.add(Conv2D(32, kernel_size=(5,5),
                  activation=activation,
                  input_shape=(img_rows, img_cols, 1)))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(64, (5, 5), activation='tanh'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Flatten())
  model.add(Dense(num_classes, activation='softmax'))
  model.summary()
  es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
  mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)

  model.compile(loss=loss,
              optimizer=optimizer,
              metrics=['accuracy'])

  history = model.fit(x_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            verbose=verbose,
            validation_data=(x_test, y_test), 
            callbacks=[es,mc])

  score = model.evaluate(x_test, y_test, verbose=0)
  print('Test loss:', score[0])
  print('Test accuracy:', score[1])

  best_model=keras.models.load_model('best_model.h5')
  test_loss, test_acc = best_model.evaluate(x_test, y_test)
  val_loss_list=history.history['val_loss']
  best_val_loss_epoch=val_loss_list.index(min(val_loss_list))
  val_acc_list = history.history["val_accuracy"]
  best_val_acc_epoch = val_acc_list.index(max(val_acc_list))

  print("loss on test set : ", test_loss)
  print("accuracy on test set : ", test_acc)
  print("\nBest epoch for the val_loss is : ", best_val_loss_epoch)
  print("\nBest epoch for the val_acc is : ", best_val_acc_epoch)

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
  y_pred = model.predict_classes(x_test)
  print(classification_report(Y_test, y_pred))
  
  return model

# %% [markdown]
# Hyperparamètres pour le RN

# %%
dicoLocs = {'nasal':1, 'non_nasal':0}
labels = [l.split('/')[-1] for l in glb.glob('drive/Shareddrives/ReseauNeurones/images_python/train/*')]
img_rows, img_cols = 28, 28
batch_size = 10
epochs = 115
num_classes = len(labels)

# %%
print(dicoLocs)
print(labels)
# Out:
# {'nasal': 1, 'non_nasal': 0}
# ['nasal', 'non_nasal']

# %% [markdown]
# Les données - images et labels

# %%
x_train, y_train, fileNames_train = getDataSet('drive/Shareddrives/ReseauNeurones/images_python/train/*/*')
x_test, y_test, fileNames = getDataSet('drive/Shareddrives/ReseauNeurones/images_python/test/*/*')

# %%
print(len(x_train), len(x_test))
print(y_train)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 19800 4950
# [[0. 1.]
#  [0. 1.]
#  [0. 1.]
#  ...
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]]
# x_train shape: (19800, 28, 28, 1)
# x_test shape: (4950, 28, 28, 1)
# 19800 train samples
# 4950 test samples

# %% [markdown]
# # Exécution du modèle

# %% [markdown]
# ##Entraînement 1
#     activation : tanh
#     model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

# %%
model = keras_RN(x_train, y_train, x_test, y_test, activation="tanh", loss="mean_squared_error", optimizer=optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.1358 - accuracy: 0.7947 - val_loss: 0.0592 - val_accuracy: 0.9214
# Epoch 2/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0480 - accuracy: 0.9362 - val_loss: 0.0605 - val_accuracy: 0.9210
# Epoch 3/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0436 - accuracy: 0.9434 - val_loss: 0.0468 - val_accuracy: 0.9398
# Epoch 4/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0394 - accuracy: 0.9493 - val_loss: 0.0451 - val_accuracy: 0.9430
# Epoch 5/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0384 - accuracy: 0.9507 - val_loss: 0.0475 - val_accuracy: 0.9378
# Epoch 6/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0358 - accuracy: 0.9533 - val_loss: 0.0481 - val_accuracy: 0.9368
# Epoch 7/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0333 - accuracy: 0.9574 - val_loss: 0.0421 - val_accuracy: 0.9453
# Epoch 8/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0324 - accuracy: 0.9581 - val_loss: 0.0453 - val_accuracy: 0.9418
# Epoch 9/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0313 - accuracy: 0.9612 - val_loss: 0.0462 - val_accuracy: 0.9420
# Epoch 10/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0278 - accuracy: 0.9662 - val_loss: 0.0421 - val_accuracy: 0.9422
# Epoch 11/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0276 - accuracy: 0.9662 - val_loss: 0.0407 - val_accuracy: 0.9461
# Epoch 12/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0274 - accuracy: 0.9662 - val_loss: 0.0405 - val_accuracy: 0.9479
# Epoch 13/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0257 - accuracy: 0.9693 - val_loss: 0.0400 - val_accuracy: 0.9485
# Epoch 14/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0228 - accuracy: 0.9715 - val_loss: 0.0401 - val_accuracy: 0.9469
# Epoch 15/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0245 - accuracy: 0.9705 - val_loss: 0.0386 - val_accuracy: 0.9491
# Epoch 16/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0217 - accuracy: 0.9746 - val_loss: 0.0447 - val_accuracy: 0.9412
# Epoch 17/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0212 - accuracy: 0.9746 - val_loss: 0.0381 - val_accuracy: 0.9513
# Epoch 18/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0210 - accuracy: 0.9748 - val_loss: 0.0384 - val_accuracy: 0.9505
# Epoch 19/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0187 - accuracy: 0.9788 - val_loss: 0.0379 - val_accuracy: 0.9515
# Epoch 20/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0185 - accuracy: 0.9792 - val_loss: 0.0397 - val_accuracy: 0.9497
# Epoch 21/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0184 - accuracy: 0.9789 - val_loss: 0.0384 - val_accuracy: 0.9503
# Epoch 22/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0150 - accuracy: 0.9835 - val_loss: 0.0386 - val_accuracy: 0.9495
# Epoch 23/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0161 - accuracy: 0.9828 - val_loss: 0.0392 - val_accuracy: 0.9493
# Epoch 24/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9830 - val_loss: 0.0388 - val_accuracy: 0.9509
# Epoch 25/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0135 - accuracy: 0.9863 - val_loss: 0.0389 - val_accuracy: 0.9493
# Epoch 26/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9841 - val_loss: 0.0399 - val_accuracy: 0.9475
# Epoch 27/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0120 - accuracy: 0.9878 - val_loss: 0.0401 - val_accuracy: 0.9477
# Epoch 28/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0120 - accuracy: 0.9862 - val_loss: 0.0418 - val_accuracy: 0.9475
# Epoch 29/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0108 - accuracy: 0.9893 - val_loss: 0.0397 - val_accuracy: 0.9485
# Epoch 30/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0100 - accuracy: 0.9900 - val_loss: 0.0399 - val_accuracy: 0.9485
# Epoch 31/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0088 - accuracy: 0.9918 - val_loss: 0.0408 - val_accuracy: 0.9487
# Epoch 32/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0081 - accuracy: 0.9930 - val_loss: 0.0409 - val_accuracy: 0.9491
# Epoch 33/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.
115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0053 - accuracy: 0.9949 - val_loss: 0.0414 - val_accuracy: 0.9495
# Epoch 65/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0046 - accuracy: 0.9955 - val_loss: 0.0412 - val_accuracy: 0.9501
# Epoch 66/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0043 - accuracy: 0.9959 - val_loss: 0.0414 - val_accuracy: 0.9501
# Epoch 67/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0041 - accuracy: 0.9961 - val_loss: 0.0419 - val_accuracy: 0.9489
# Epoch 68/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0037 - accuracy: 0.9965 - val_loss: 0.0416 - val_accuracy: 0.9499
# Epoch 69/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0043 - accuracy: 0.9959 - val_loss: 0.0417 - val_accuracy: 0.9495
# Epoch 00069: early stopping
# Test loss: 0.04173816367983818
# Test accuracy: 0.9494949579238892
# 155/155 [==============================] - 0s 1ms/step - loss: 0.0379 - accuracy: 0.9515
# loss on test set :  0.03792480006814003
# accuracy on test set :  0.9515151381492615
#
# Best epoch for the val_loss is :  18
#
# Best epoch for the val_acc is :  48
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95      2475
#            1       0.95      0.94      0.95      2475
#
#     accuracy                           0.95      4950
#    macro avg       0.95      0.95      0.95      4950
# weighted avg       0.95      0.95      0.95      4950

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model1')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model1/assets

# %%
model = tf.keras.models.load_model('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model1')

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %%
testLocuteur(model, "drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_loc_entrainement1.csv", "drive/Shareddrives/ReseauNeurones/images_python/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
testSegment(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_seg_entrainement1.csv", "/content/drive/Shareddrives/ReseauNeurones/images_python/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
proba = model.predict_proba(x_test)
print(proba)
# Out:
# [[9.9228448e-01 7.7155544e-03]
#  [9.9104828e-01 8.9517394e-03]
#  [9.9970430e-01 2.9568610e-04]
#  ...
#  [1.7822448e-03 9.9821776e-01]
#  [1.7897616e-08 1.0000000e+00]
#  [8.8894024e-02 9.1110593e-01]]
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '

# %%
print(proba[0])
for i in proba[0]:
  print(f"{i:.6f}")
# Out:
# [0.9922845  0.00771555]
# 0.992284
# 0.007716

# %%
resultat = dict()

for i in range(len(proba)):
  score = dict()
  score["son"] = fileNames[i].split('_')[6]
  score["contexte_gauche"] = fileNames[i].split('_')[-4]
  score["contexte_droit"] = fileNames[i].split('_')[-3]
  score["contextes"] = fileNames[i].split('_')[-4] + "_" + fileNames[i].split('_')[-3]
  score["proba_oral"] = f"{proba[i][0]:.6f}"
  score["proba_nasal"] = f"{proba[i][1]:.6f}"
  resultat[i+1] = score

getCSV(resultat, "drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_contexte_entrainement1.csv")

# %% [markdown]
# ##Entraînement 2
#     activation : relu
#     model.compile(loss=keras.losses.categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])

# %%
model = keras_RN(x_train, y_train, x_test, y_test, activation="relu", loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adadelta())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.6904 - accuracy: 0.5120 - val_loss: 0.6817 - val_accuracy: 0.6673
# Epoch 2/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.6783 - accuracy: 0.6503 - val_loss: 0.6707 - val_accuracy: 0.7053
# Epoch 3/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.6671 - accuracy: 0.6917 - val_loss: 0.6591 - val_accuracy: 0.6972
# Epoch 4/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.6543 - accuracy: 0.6980 - val_loss: 0.6466 - val_accuracy: 0.7059
# Epoch 5/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0
115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3830 - accuracy: 0.8296 - val_loss: 0.3919 - val_accuracy: 0.8204
# Epoch 99/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3847 - accuracy: 0.8311 - val_loss: 0.3905 - val_accuracy: 0.8224
# Epoch 100/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3840 - accuracy: 0.8283 - val_loss: 0.3893 - val_accuracy: 0.8251
# Epoch 101/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3770 - accuracy: 0.8363 - val_loss: 0.3878 - val_accuracy: 0.8236
# Epoch 102/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3785 - accuracy: 0.8353 - val_loss: 0.3871 - val_accuracy: 0.8236
# Epoch 103/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.3804 - accuracy: 0.8313 - val_loss: 0.3852 - val_accuracy: 0.8255
# Epoch 104/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3790 - accuracy: 0.8339 - val_loss: 0.3850 - val_accuracy: 0.8253
# Epoch 105/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3680 - accuracy: 0.8415 - val_loss: 0.3826 - val_accuracy: 0.8257
# Epoch 106/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3761 - accuracy: 0.8353 - val_loss: 0.3812 - val_accuracy: 0.8305
# Epoch 107/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3703 - accuracy: 0.8381 - val_loss: 0.3797 - val_accuracy: 0.8299
# Epoch 108/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.3637 - accuracy: 0.8441 - val_loss: 0.3785 - val_accuracy: 0.8315
# Epoch 109/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3681 - accuracy: 0.8408 - val_loss: 0.3770 - val_accuracy: 0.8313
# Epoch 110/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3717 - accuracy: 0.8381 - val_loss: 0.3757 - val_accuracy: 0.8339
# Epoch 111/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3674 - accuracy: 0.8409 - val_loss: 0.3744 - val_accuracy: 0.8352
# Epoch 112/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3632 - accuracy: 0.8438 - val_loss: 0.3730 - val_accuracy: 0.8343
# Epoch 113/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3619 - accuracy: 0.8462 - val_loss: 0.3716 - val_accuracy: 0.8366
# Epoch 114/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3604 - accuracy: 0.8462 - val_loss: 0.3704 - val_accuracy: 0.8364
# Epoch 115/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3617 - accuracy: 0.8444 - val_loss: 0.3692 - val_accuracy: 0.8410
# Test loss: 0.3691539466381073
# Test accuracy: 0.8410100936889648
# 155/155 [==============================] - 0s 2ms/step - loss: 0.3692 - accuracy: 0.8410
# loss on test set :  0.3691539466381073
# accuracy on test set :  0.8410100936889648
#
# Best epoch for the val_loss is :  114
#
# Best epoch for the val_acc is :  114
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85      2475
#            1       0.86      0.81      0.84      2475
#
#     accuracy                           0.84      4950
#    macro avg       0.84      0.84      0.84      4950
# weighted avg       0.84      0.84      0.84      4950
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model2')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model2/assets

# %%
model = tf.keras.models.load_model('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model2')

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %%
testLocuteur(model, "drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_loc_entrainement2.csv", "drive/Shareddrives/ReseauNeurones/images_python/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
testSegment(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_seg_entrainement2.csv", "/content/drive/Shareddrives/ReseauNeurones/images_python/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
proba = model.predict_proba(x_test)
print(proba)
# Out:
# [[0.86374515 0.13625486]
#  [0.79399395 0.20600608]
#  [0.35408297 0.645917  ]
#  ...
#  [0.37002727 0.62997276]
#  [0.06686935 0.9331307 ]
#  [0.92996967 0.07003039]]
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '

# %%
print(proba[0])
for i in proba[0]:
  print(f"{i:.6f}")
# Out:
# [0.86374515 0.13625486]
# 0.863745
# 0.136255

# %%
resultat = dict()

for i in range(len(proba)):
  score = dict()
  score["son"] = fileNames[i].split('_')[6]
  score["contexte_gauche"] = fileNames[i].split('_')[-4]
  score["contexte_droit"] = fileNames[i].split('_')[-3]
  score["contextes"] = fileNames[i].split('_')[-4] + "_" + fileNames[i].split('_')[-3]
  score["proba_oral"] = f"{proba[i][0]:.6f}"
  score["proba_nasal"] = f"{proba[i][1]:.6f}"
  resultat[i+1] = score

getCSV(resultat, "drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_contexte_entrainement2.csv")

# %% [markdown]
# ##Entraînement 3
#     activation : tanh
#     model.compile(loss=keras.losses.categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])

# %%
model = keras_RN(x_train, y_train, x_test, y_test, activation="tanh", loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adadelta())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.7024 - accuracy: 0.5337 - val_loss: 0.6681 - val_accuracy: 0.6689
# Epoch 2/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.6619 - accuracy: 0.6745 - val_loss: 0.6480 - val_accuracy: 0.6980
# Epoch 3/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.6417 - accuracy: 0.7073 - val_loss: 0.6293 - val_accuracy: 0.7087
# Epoch 4/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.6230 - accuracy: 0.7134 - val_loss: 0.6125 - val_accuracy: 0.7154
# Epoch 5/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.6074 - accuracy: 0.7101 - val_loss: 0.5980 - val_accuracy: 0.7147
# Epoch 6/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5899 - accuracy: 0.7251 - val_loss: 0.5854 - val_accuracy: 0.7202
# Epoch 7/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5780 - accuracy: 0.7196 - val_loss: 0.5737 - val_accuracy: 0.7206
# Epoch 8/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5667 - accuracy: 0.7231 - val_loss: 0.5642 - val_accuracy: 0.7263
# Epoch 9/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5607 - accuracy: 0.7182 - val_loss: 0.5548 - val_accuracy: 0.7244
# Epoch 10/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5501 - accuracy: 0.7254 - val_loss: 0.5471 - val_accuracy: 0.7277
# Epoch 11/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5410 - accuracy: 0.7295 - val_loss: 0.5403 - val_accuracy: 0.7259
# Epoch 12/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5344 - accuracy: 0.7281 - val_loss: 0.5339 - val_accuracy: 0.7271
# Epoch 13/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5289 - accuracy: 0.7309 - val_loss: 0.5282 - val_accuracy: 0.7333
# Epoch 14/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5225 - accuracy: 0.7350 - val_loss: 0.5232 - val_accuracy: 0.7337
# Epoch 15/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5134 - accuracy: 0.7405 - val_loss: 0.5186 - val_accuracy: 0.7354
# Epoch 16/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5142 - accuracy: 0.7416 - val_loss: 0.5144 - val_accuracy: 0.7386
# Epoch 17/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5115 - accuracy: 0.7415 - val_loss: 0.5106 - val_accuracy: 0.7398
# Epoch 18/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.5020 - accuracy: 0.7471 - val_loss: 0.5072 - val_accuracy: 0.7400
# Epoch 19/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4995 - accuracy: 0.7501 - val_loss: 0.5038 - val_accuracy: 0.7453
# Epoch 20/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.4976 - accuracy: 0.7471 - val_loss: 0.5006 - val_accuracy: 0.7465
# Epoch 21/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4901 - accuracy: 0.7563 - val_loss: 0.4976 - val_accuracy: 0.7473
# Epoch 22/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4908 - accuracy: 0.7543 - val_loss: 0.4948 - val_accuracy: 0.7479
# Epoch 23/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4920 - accuracy: 0.7515 - val_loss: 0.4925 - val_accuracy: 0.7469
# Epoch 24/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4852 - accuracy: 0.7583 - val_loss: 0.4896 - val_accuracy: 0.7501
# Epoch 25/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.4894 - accuracy: 0.7489 - val_loss: 0.4871 - val_accuracy: 0.7503
# Epoch 26/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.4809 - accuracy: 0.7620 - val_loss: 0.4849 - val_accuracy: 0.7519
# Epoch 27/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4827 - accuracy: 0.7591 - val_loss: 0.4827 - val_accuracy: 0.7529
# Epoch 28/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.4787 - accuracy: 0.7624 - val_loss: 0.4807 - val_accuracy: 0.7539
# Epoch 29/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.4754 - accuracy: 0.7628 - val_loss: 0.4787 - val_accuracy: 0.7552
# Epoch 30/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.4725 - accuracy: 0.7672 - val_loss: 0.4768 - val_accuracy: 0.7560
# Epoch 31/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4702 - accuracy: 0.7677 - val_loss: 0.4752 - val_accuracy: 0.7580
# Epoch 32/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4698 - accuracy: 0.7678 - val_loss: 0.4730 - val_accuracy: 0.7584
# Epoch 33/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4650 - accuracy: 0.7722 - val_loss: 0.4712 - val_accuracy: 0.7608
# Epoch 34/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4682 - accuracy: 0.7651 - val_loss: 0.4695 - val_accuracy: 0.7620
# Epoch 35/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4597 - accuracy: 0.7768 - val_loss: 0.4681 - val_accuracy: 0.7622
# Epoch 36/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4599 - accuracy: 0.7751 - val_loss: 0.4665 - val_accuracy: 0.7634
# Epoch 37/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4602 - accuracy: 0.7743 - val_loss: 0.4647 - val_accuracy: 0.7632
# Epoch 38/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4545 - accuracy: 0.7756 - val_loss: 0.4631 - val_accuracy: 0.7653
# Epoch 39/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4561 - accuracy: 0.7790 - val_loss: 0.4615 - val_accuracy: 0.7679
# Epoch 40/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4582 - accuracy: 0.7756 - val_loss: 0.4607 - val_accuracy: 0.7671
# Epoch 41/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4574 - accuracy: 0.7743 - val_loss: 0.4587 - val_accuracy: 0.7701
# Epoch 42/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4538 - accuracy: 0.7805 - val_loss: 0.4574 - val_accuracy: 0.7699
# Epoch 43/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4512 - accuracy: 0.7807 - val_loss: 0.4557 - val_accuracy: 0.7723
# Epoch 44/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4477 - accuracy: 0.7839 - val_loss: 0.4543 - val_accuracy: 0.7733
# Epoch 45/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.4454 - accuracy: 0.7835 - val_loss: 0.4531 - val_accuracy: 0.7735
# Epoch 46/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4446 - accuracy: 0.7894 - val_loss: 0.4523 - val_accuracy: 0.7749
# Epoch 47/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4416 - accuracy: 0.7882 - val_loss: 0.4504 - val_accuracy: 0.7760
# Epoch 48/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4426 - accuracy: 0.7867 - val_loss: 0.4488 - val_accuracy: 0.7784
# Epoch 49/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4452 - accuracy: 0.7911 - val_loss: 0.4475 - val_accuracy: 0.7792
# Epoch 50/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4440 - accuracy: 0.7859 - val_loss: 0.4462 - val_accuracy: 0.7818
# Epoch 51/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4369 - accuracy: 0.7931 - val_loss: 0.4449 - val_accuracy: 0.7810
# Epoch 52/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4360 - accuracy: 0.7893 - val_loss: 0.4435 - val_accuracy: 0.7830
# Epoch 53/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4353 - accuracy: 0.7979 - val_loss: 0.4422 - val_accuracy: 0.7830
# Epoch 54/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.4346 - accuracy: 0.7938 - val_loss: 0.4408 - val_accuracy: 0.7848
# Epoch 55/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.4328 - accuracy: 0.7955 - val_loss: 0.4396 - val_accuracy: 0.7859
# Epoch 56/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.4305 - accuracy: 0.7980 - val_loss: 0.4382 - val_accuracy: 0.7867
# Epoch 57/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4310 - accuracy: 0.7983 - val_loss: 0.4370 - val_accuracy: 0.7875
# Epoch 58/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4301 - accuracy: 0.8019 - val_loss: 0.4362 - val_accuracy: 0.7883
# Epoch 59/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4320 - accuracy: 0.7932 - val_loss: 0.4347 - val_accuracy: 0.7883
# Epoch 60/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4239 - accuracy: 0.8007 - val_loss: 0.4331 - val_accuracy: 0.7905
# Epoch 61/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4237 - accuracy: 0.8025 - val_loss: 0.4318 - val_accuracy: 0.7913
# Epoch 62/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4224 - accuracy: 0.8045 - val_loss: 0.4305 - val_accuracy: 0.7921
# Epoch 63/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4184 - accuracy: 0.8083 - val_loss: 0.4296 - val_accuracy: 0.7917
# Epoch 64/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4175 - accuracy: 0.8052 - val_loss: 0.4281 - val_accuracy: 0.7927
# Epoch 65/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4212 - accuracy: 0.8027 - val_loss: 0.4267 - val_accuracy: 0.7935
# Epoch 66/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4192 - accuracy: 0.8092 - val_loss: 0.4255 - val_accuracy: 0.7949
# Epoch 67/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4172 - accuracy: 0.8063 - val_loss: 0.4244 - val_accuracy: 0.7960
# Epoch 68/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4144 - accuracy: 0.8075 - val_loss: 0.4227 - val_accuracy: 0.7978
# Epoch 69/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4150 - accuracy: 0.8093 - val_loss: 0.4221 - val_accuracy: 0.7970
# Epoch 70/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4193 - accuracy: 0.8078 - val_loss: 0.4203 - val_accuracy: 0.8000
# Epoch 71/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4128 - accuracy: 0.8110 - val_loss: 0.4190 - val_accuracy: 0.8032
# Epoch 72/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.4151 - accuracy: 0.8100 - val_loss: 0.4182 - val_accuracy: 0.7996
# Epoch 73/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4103 - accuracy: 0.8098 - val_loss: 0.4163 - val_accuracy: 0.8026
# Epoch 74/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4094 - accuracy: 0.8147 - val_loss: 0.4151 - val_accuracy: 0.8036
# Epoch 75/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4040 - accuracy: 0.8164 - val_loss: 0.4137 - val_accuracy: 0.8053
# Epoch 76/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4068 - accuracy: 0.8161 - val_loss: 0.4123 - val_accuracy: 0.8071
# Epoch 77/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4011 - accuracy: 0.8155 - val_loss: 0.4110 - val_accuracy: 0.8083
# Epoch 78/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4068 - accuracy: 0.8163 - val_loss: 0.4098 - val_accuracy: 0.8095
# Epoch 79/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4038 - accuracy: 0.8180 - val_loss: 0.4084 - val_accuracy: 0.8099
# Epoch 80/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.4022 - accuracy: 0.8197 - val_loss: 0.4070 - val_accuracy: 0.8129
# Epoch 81/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3981 - accuracy: 0.8238 - val_loss: 0.4057 - val_accuracy: 0.8137
# Epoch 82/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.3980 - accuracy: 0.8228 - val_loss: 0.4047 - val_accuracy: 0.8109
# Epoch 83/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.3942 - accuracy: 0.8226 - val_loss: 0.4031 - val_accuracy: 0.8135
# Epoch 84/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3975 - accuracy: 0.8204 - val_loss: 0.4016 - val_accuracy: 0.8182
# Epoch 85/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3937 - accuracy: 0.8236 - val_loss: 0.4003 - val_accuracy: 0.8198
# Epoch 86/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3863 - accuracy: 0.8294 - val_loss: 0.3988 - val_accuracy: 0.8204
# Epoch 87/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3916 - accuracy: 0.8231 - val_loss: 0.3975 - val_accuracy: 0.8220
# Epoch 88/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3925 - accuracy: 0.8237 - val_loss: 0.3961 - val_accuracy: 0.8214
# Epoch 89/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3840 - accuracy: 0.8303 - val_loss: 0.3949 - val_accuracy: 0.8202
# Epoch 90/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3880 - accuracy: 0.8268 - val_loss: 0.3939 - val_accuracy: 0.8196
# Epoch 91/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3855 - accuracy: 0.8282 - val_loss: 0.3920 - val_accuracy: 0.8238
# Epoch 92/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3818 - accuracy: 0.8306 - val_loss: 0.3907 - val_accuracy: 0.8234
# Epoch 93/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3857 - accuracy: 0.8308 - val_loss: 0.3905 - val_accuracy: 0.8220
# Epoch 94/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3759 - accuracy: 0.8359 - val_loss: 0.3882 - val_accuracy: 0.8251
# Epoch 95/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3803 - accuracy: 0.8371 - val_loss: 0.3864 - val_accuracy: 0.8261
# Epoch 96/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3785 - accuracy: 0.8337 - val_loss: 0.3857 - val_accuracy: 0.8259
# Epoch 97/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3735 - accuracy: 0.8391 - val_loss: 0.3835 - val_accuracy: 0.8307
# Epoch 98/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.3752 - accuracy: 0.8396 - val_loss: 0.3820 - val_accuracy: 0.8319
# Epoch 99/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.3740 - accuracy: 0.8380 - val_loss: 0.3811 - val_accuracy: 0.8291
# Epoch 100/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.3744 - accuracy: 0.8376 - val_loss: 0.3792 - val_accuracy: 0.8337
# Epoch 101/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3690 - accuracy: 0.8447 - val_loss: 0.3780 - val_accuracy: 0.8319
# Epoch 102/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3692 - accuracy: 0.8409 - val_loss: 0.3764 - val_accuracy: 0.8354
# Epoch 103/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3605 - accuracy: 0.8464 - val_loss: 0.3753 - val_accuracy: 0.8337
# Epoch 104/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3668 - accuracy: 0.8421 - val_loss: 0.3748 - val_accuracy: 0.8331
# Epoch 105/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3663 - accuracy: 0.8424 - val_loss: 0.3730 - val_accuracy: 0.8347
# Epoch 106/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3574 - accuracy: 0.8507 - val_loss: 0.3707 - val_accuracy: 0.8396
# Epoch 107/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3617 - accuracy: 0.8481 - val_loss: 0.3697 - val_accuracy: 0.8374
# Epoch 108/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3634 - accuracy: 0.8441 - val_loss: 0.3678 - val_accuracy: 0.8420
# Epoch 109/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3609 - accuracy: 0.8467 - val_loss: 0.3665 - val_accuracy: 0.8424
# Epoch 110/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3574 - accuracy: 0.8489 - val_loss: 0.3652 - val_accuracy: 0.8424
# Epoch 111/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3540 - accuracy: 0.8504 - val_loss: 0.3637 - val_accuracy: 0.8438
# Epoch 112/115
# 1980/1980 [==============================] - 5s 2ms/step - loss: 0.3552 - accuracy: 0.8499 - val_loss: 0.3622 - val_accuracy: 0.8442
# Epoch 113/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3558 - accuracy: 0.8498 - val_loss: 0.3607 - val_accuracy: 0.8463
# Epoch 114/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3542 - accuracy: 0.8525 - val_loss: 0.3593 - val_accuracy: 0.8469
# Epoch 115/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.3489 - accuracy: 0.8544 - val_loss: 0.3583 - val_accuracy: 0.8463
# Test loss: 0.3582763075828552
# Test accuracy: 0.8462626338005066
# 155/155 [==============================] - 0s 2ms/step - loss: 0.3583 - accuracy: 0.8463
# loss on test set :  0.3582763075828552
# accuracy on test set :  0.8462626338005066
#
# Best epoch for the val_loss is :  114
#
# Best epoch for the val_acc is :  113
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85      2475
#            1       0.88      0.80      0.84      2475
#
#     accuracy                           0.85      4950
#    macro avg       0.85      0.85      0.85      4950
# weighted avg       0.85      0.85      0.85      4950
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model3')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model3/assets

# %%
model = tf.keras.models.load_model('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model3')

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %%
testLocuteur(model, "drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_loc_entrainement3.csv", "drive/Shareddrives/ReseauNeurones/images_python/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
testSegment(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_seg_entrainement3.csv", "/content/drive/Shareddrives/ReseauNeurones/images_python/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
proba = model.predict_proba(x_test)
print(proba)
# Out:
# [[0.8553066  0.1446934 ]
#  [0.8734444  0.12655565]
#  [0.4015231  0.59847695]
#  ...
#  [0.35270342 0.6472966 ]
#  [0.08076499 0.91923505]
#  [0.9293905  0.07060952]]
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '

# %%
print(proba[0])
for i in proba[0]:
  print(f"{i:.6f}")
# Out:
# [0.8553066 0.1446934]
# 0.855307
# 0.144693

# %%
resultat = dict()

for i in range(len(proba)):
  score = dict()
  score["son"] = fileNames[i].split('_')[6]
  score["contexte_gauche"] = fileNames[i].split('_')[-4]
  score["contexte_droit"] = fileNames[i].split('_')[-3]
  score["contextes"] = fileNames[i].split('_')[-4] + "_" + fileNames[i].split('_')[-3]
  score["proba_oral"] = f"{proba[i][0]:.6f}"
  score["proba_nasal"] = f"{proba[i][1]:.6f}"
  resultat[i+1] = score

getCSV(resultat, "drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_contexte_entrainement3.csv")

# %% [markdown]
# ##Entraînement 4
#     activation : relu
#     model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

# %%
model = keras_RN(x_train, y_train, x_test, y_test, activation="relu", loss="mean_squared_error", optimizer=optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.1426 - accuracy: 0.7849 - val_loss: 0.0544 - val_accuracy: 0.9293
# Epoch 2/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0509 - accuracy: 0.9327 - val_loss: 0.0489 - val_accuracy: 0.9364
# Epoch 3/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0447 - accuracy: 0.9412 - val_loss: 0.0529 - val_accuracy: 0.9303
# Epoch 4/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0416 - accuracy: 0.9453 - val_loss: 0.0475 - val_accuracy: 0.9382
# Epoch 5/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0408 - accuracy: 0.9464 - val_loss: 0.0434 - val_accuracy: 0.9428
# Epoch 6/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0362 - accuracy: 0.9549 - val_loss: 0.0483 - val_accuracy: 0.9372
# Epoch 7/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0366 - accuracy: 0.9531 - val_loss: 0.0420 - val_accuracy: 0.9440
# Epoch 8/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0342 - accuracy: 0.9553 - val_loss: 0.0416 - val_accuracy: 0.9451
# Epoch 9/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0334 - accuracy: 0.9571 - val_loss: 0.0397 - val_accuracy: 0.9475
# Epoch 10/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0309 - accuracy: 0.9598 - val_loss: 0.0462 - val_accuracy: 0.9396
# Epoch 11/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0318 - accuracy: 0.9588 - val_loss: 0.0412 - val_accuracy: 0.9465
# Epoch 12/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0287 - accuracy: 0.9633 - val_loss: 0.0382 - val_accuracy: 0.9489
# Epoch 13/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0276 - accuracy: 0.9657 - val_loss: 0.0404 - val_accuracy: 0.9473
# Epoch 14/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0282 - accuracy: 0.9640 - val_loss: 0.0397 - val_accuracy: 0.9473
# Epoch 15/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0251 - accuracy: 0.9695 - val_loss: 0.0371 - val_accuracy: 0.9493
# Epoch 16/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0265 - accuracy: 0.9674 - val_loss: 0.0372 - val_accuracy: 0.9525
# Epoch 17/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0249 - accuracy: 0.9690 - val_loss: 0.0374 - val_accuracy: 0.9499
# Epoch 18/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0232 - accuracy: 0.9709 - val_loss: 0.0374 - val_accuracy: 0.9519
# Epoch 19/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0218 - accuracy: 0.9729 - val_loss: 0.0388 - val_accuracy: 0.9495
# Epoch 20/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0218 - accuracy: 0.9749 - val_loss: 0.0380 - val_accuracy: 0.9499
# Epoch 21/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0208 - accuracy: 0.9755 - val_loss: 0.0439 - val_accuracy: 0.9426
# Epoch 22/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0181 - accuracy: 0.9782 - val_loss: 0.0385 - val_accuracy: 0.9499
# Epoch 23/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0191 - accuracy: 0.9783 - val_loss: 0.0379 - val_accuracy: 0.9513
# Epoch 24/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0181 - accuracy: 0.9788 - val_loss: 0.0386 - val_accuracy: 0.9479
# Epoch 25/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0186 - accuracy: 0.9798 - val_loss: 0.0394 - val_accuracy: 0.9493
# Epoch 26/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0157 - accuracy: 0.9821 - val_loss: 0.0379 - val_accuracy: 0.9513
# Epoch 27/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9820 - val_loss: 0.0386 - val_accuracy: 0.9509
# Epoch 28/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0137 - accuracy: 0.9848 - val_loss: 0.0411 - val_accuracy: 0.9463
# Epoch 29/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0124 - accuracy: 0.9865 - val_loss: 0.0377 - val_accuracy: 0.9503
# Epoch 30/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0132 - accuracy: 0.9864 - val_loss: 0.0446 - val_accuracy: 0.9436
# Epoch 31/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0121 - accuracy: 0.9873 - val_loss: 0.0407 - val_accuracy: 0.9469
# Epoch 32/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0113 - accuracy: 0.9884 - val_loss: 0.0390 - val_accuracy: 0.9493
# Epoch 33/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0102 - accuracy: 0.9893 - val_loss: 0.0383 - val_accuracy: 0.9513
# Epoch 34/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0104 - accuracy: 0.9901 - val_loss: 0.0393 - val_accuracy: 0.9511
# Epoch 35/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0104 - accuracy: 0.9901 - val_loss: 0.0396 - val_accuracy: 0.9499
# Epoch 36/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0092 - accuracy: 0.9909 - val_loss: 0.0400 - val_accuracy: 0.9483
# Epoch 37/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0082 - accuracy: 0.9926 - val_loss: 0.0386 - val_accuracy: 0.9509
# Epoch 38/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0075 - accuracy: 0.9936 - val_loss: 0.0403 - val_accuracy: 0.9497
# Epoch 39/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0071 - accuracy: 0.9939 - val_loss: 0.0408 - val_accuracy: 0.9477
# Epoch 40/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0072 - accuracy: 0.9934 - val_loss: 0.0398 - val_accuracy: 0.9511
# Epoch 41/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0060 - accuracy: 0.9947 - val_loss: 0.0395 - val_accuracy: 0.9497
# Epoch 42/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0065 - accuracy: 0.9945 - val_loss: 0.0396 - val_accuracy: 0.9507
# Epoch 43/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0061 - accuracy: 0.9944 - val_loss: 0.0417 - val_accuracy: 0.9481
# Epoch 44/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0054 - accuracy: 0.9953 - val_loss: 0.0405 - val_accuracy: 0.9491
# Epoch 45/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0055 - accuracy: 0.9951 - val_loss: 0.0400 - val_accuracy: 0.9497
# Epoch 46/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0048 - accuracy: 0.9956 - val_loss: 0.0394 - val_accuracy: 0.9507
# Epoch 47/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0060 - accuracy: 0.9945 - val_loss: 0.0402 - val_accuracy: 0.9501
# Epoch 48/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0045 - accuracy: 0.9961 - val_loss: 0.0403 - val_accuracy: 0.9491
# Epoch 49/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0045 - accuracy: 0.9960 - val_loss: 0.0402 - val_accuracy: 0.9499
# Epoch 50/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0041 - accuracy: 0.9963 - val_loss: 0.0404 - val_accuracy: 0.9497
# Epoch 51/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0044 - accuracy: 0.9960 - val_loss: 0.0405 - val_accuracy: 0.9501
# Epoch 52/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0039 - accuracy: 0.9964 - val_loss: 0.0402 - val_accuracy: 0.9495
# Epoch 53/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0044 - accuracy: 0.9959 - val_loss: 0.0404 - val_accuracy: 0.9497
# Epoch 54/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0042 - accuracy: 0.9962 - val_loss: 0.0405 - val_accuracy: 0.9499
# Epoch 55/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0047 - accuracy: 0.9956 - val_loss: 0.0404 - val_accuracy: 0.9505
# Epoch 56/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0051 - accuracy: 0.9952 - val_loss: 0.0405 - val_accuracy: 0.9497
# Epoch 57/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0043 - accuracy: 0.9960 - val_loss: 0.0400 - val_accuracy: 0.9503
# Epoch 58/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0039 - accuracy: 0.9963 - val_loss: 0.0405 - val_accuracy: 0.9497
# Epoch 59/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0047 - accuracy: 0.9956 - val_loss: 0.0406 - val_accuracy: 0.9497
# Epoch 60/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0035 - accuracy: 0.9968 - val_loss: 0.0404 - val_accuracy: 0.9493
# Epoch 61/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0049 - accuracy: 0.9952 - val_loss: 0.0405 - val_accuracy: 0.9503
# Epoch 62/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0030 - accuracy: 0.9972 - val_loss: 0.0408 - val_accuracy: 0.9495
# Epoch 63/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0045 - accuracy: 0.9958 - val_loss: 0.0405 - val_accuracy: 0.9501
# Epoch 64/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0035 - accuracy: 0.9967 - val_loss: 0.0407 - val_accuracy: 0.9493
# Epoch 65/115
# 1980/1980 [==============================] - 4s 2ms/step - loss: 0.0042 - accuracy: 0.9960 - val_loss: 0.0407 - val_accuracy: 0.9503
# Epoch 00065: early stopping
# Test loss: 0.040743906050920486
# Test accuracy: 0.9503030180931091
# 155/155 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 0.9493
# loss on test set :  0.037117067724466324
# accuracy on test set :  0.9492929577827454
#
# Best epoch for the val_loss is :  14
#
# Best epoch for the val_acc is :  15
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      2475
#            1       0.96      0.94      0.95      2475
#
#     accuracy                           0.95      4950
#    macro avg       0.95      0.95      0.95      4950
# weighted avg       0.95      0.95      0.95      4950
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model4')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model4/assets

# %%
model = tf.keras.models.load_model('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/python_train_aA_test_aA_model4')

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %%
testLocuteur(model, "drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_loc_entrainement4.csv", "drive/Shareddrives/ReseauNeurones/images_python/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
testSegment(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_seg_entrainement4.csv", "/content/drive/Shareddrives/ReseauNeurones/images_python/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
proba = model.predict_proba(x_test)
print(proba)
# Out:
# [[9.9713576e-01 2.8641990e-03]
#  [9.8097527e-01 1.9024719e-02]
#  [9.9991500e-01 8.5015257e-05]
#  ...
#  [1.2393181e-04 9.9987602e-01]
#  [1.4476117e-07 9.9999988e-01]
#  [5.7229400e-01 4.2770600e-01]]
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '

# %%
print(proba[0])
for i in proba[0]:
  print(f"{i:.6f}")
# Out:
# [0.99713576 0.0028642 ]
# 0.997136
# 0.002864

# %%
resultat = dict()

for i in range(len(proba)):
  score = dict()
  score["son"] = fileNames[i].split('_')[6]
  score["contexte_gauche"] = fileNames[i].split('_')[-4]
  score["contexte_droit"] = fileNames[i].split('_')[-3]
  score["contextes"] = fileNames[i].split('_')[-4] + "_" + fileNames[i].split('_')[-3]
  score["proba_oral"] = f"{proba[i][0]:.6f}"
  score["proba_nasal"] = f"{proba[i][1]:.6f}"
  resultat[i+1] = score

getCSV(resultat, "drive/Shareddrives/ReseauNeurones/resume_resultats/non_troncons/aA_python/all_score_contexte_entrainement4.csv")

# %% [markdown]
# ---
#
# ---
#
#
#
#
#
# Et quelques autres entraînements pour essayer de voir d'où vient la différence au niveau de la progression dans un entraînement...
#
#
# ---
#
# ---

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(5,5),
                 activation='relu',
                 input_shape=(img_rows, img_cols, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (5, 5), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
model.summary()
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

# model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

model.compile(loss='mean_squared_error',
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test), 
          callbacks=[es,mc])

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

best_model=keras.models.load_model('best_model.h5')
test_loss, test_acc = best_model.evaluate(x_test, y_test)
val_loss_list=history.history['val_loss']
best_val_loss_epoch=val_loss_list.index(min(val_loss_list))
val_acc_list = history.history["val_accuracy"]
best_val_acc_epoch = val_acc_list.index(max(val_acc_list))

print("loss on test set : ", test_loss)
print("accuracy on test set : ", test_acc)
print("\nBest epoch for the val_loss is : ", best_val_loss_epoch)
print("\nBest epoch for the val_acc is : ", best_val_acc_epoch)

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(5,5),
                 activation='relu',
                 input_shape=(img_rows, img_cols, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (5, 5), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
model.summary()
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

# model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=sgd,
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test), 
          callbacks=[es,mc])

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

best_model=keras.models.load_model('best_model.h5')
test_loss, test_acc = best_model.evaluate(x_test, y_test)
val_loss_list=history.history['val_loss']
best_val_loss_epoch=val_loss_list.index(min(val_loss_list))
val_acc_list = history.history["val_accuracy"]
best_val_acc_epoch = val_acc_list.index(max(val_acc_list))

print("loss on test set : ", test_loss)
print("accuracy on test set : ", test_acc)
print("\nBest epoch for the val_loss is : ", best_val_loss_epoch)
print("\nBest epoch for the val_acc is : ", best_val_acc_epoch)

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
