# %%
# !pip install pandas_ml
# !pip install scikit-learn==0.21
# !pip install pandas==0.24.2
# Out:
# Requirement already satisfied: pandas_ml in /usr/local/lib/python3.7/dist-packages (0.6.1)
# Requirement already satisfied: pandas>=0.19.0 in /usr/local/lib/python3.7/dist-packages (from pandas_ml) (0.24.2)
# Requirement already satisfied: enum34 in /usr/local/lib/python3.7/dist-packages (from pandas_ml) (1.1.10)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.0->pandas_ml) (2.8.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.0->pandas_ml) (1.19.5)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19.0->pandas_ml) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.5.0->pandas>=0.19.0->pandas_ml) (1.15.0)
# Requirement already satisfied: scikit-learn==0.21 in /usr/local/lib/python3.7/dist-packages (0.21.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.21) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.21) (1.0.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.21) (1.19.5)
# Requirement already satisfied: pandas==0.24.2 in /usr/local/lib/python3.7/dist-packages (0.24.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from pandas==0.24.2) (2.8.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from pandas==0.24.2) (1.19.5)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.7/dist-packages (from pandas==0.24.2) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.5.0->pandas==0.24.2) (1.15.0)

# %%
import keras
import cv2
import re
import os
import numpy as np
import matplotlib.pyplot as plt
import glob as glb
import pandas as pd
import tensorflow as tf
from __future__ import print_function
from sklearn.metrics import classification_report
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.utils import np_utils
from keras.utils import to_categorical
from pandas_ml import ConfusionMatrix
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adadelta
from keras import optimizers
from google.colab  import files, drive

drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# Mounted at /content/drive

# %%
def getCSV(resultat, path_output):
  """
  input : dict(result), str(path to csv)
  output : obj(df)
  """
  df = pd.DataFrame.from_dict(resultat, orient="index")
  # print(df)
  return df.to_csv(path_output, sep="\t", encoding="utf8")

# %% [markdown]
# ## Ecriture des résultats

# %% [markdown]
# ### Utilisation d'un dictionnaire avant de le transformer en dataframe

# %%
def getScoreLocuteur(report):
  """
  input : str(classification report)
  output : dict(scores)
  """
  lignes = report.split("\n")
  score = {}
  for n in range(1, len(lignes)):
    # print(lignes[n])
    if lignes[n] != "":
      lignes[n] = lignes[n].strip()
      if 'avg' in lignes[n]: lignes[n] = re.sub(" avg", "_avg",lignes[n])
      data = lignes[n].split()
      if data[0] != "accuracy":
        # print(data)
        score["precision_"+data[0]] = data[1]
        score["recall_"+data[0]] = data[2]
        score["f1_score_"+data[0]] = data[3]
        score["support_"+data[0]] = data[4]
      else:
        score["f1_score_"+data[0]] = data[1]
        score["support_"+data[0]] = data[2]

  return score

# %% [markdown]
# ### Initiation d'une liste pour sauvegarder les identifiants des locuteurs

# %%
def getListLocuteur(path_to_files):
  """
  input : str(path to files)
  output : list(list of speakers)
  """
  locs = list()
  for path in glb.glob(path_to_files):
    loc_file = "_".join(path.split('/')[-1].split('_')[0:6])
    if loc_file not in locs:
      locs.append(loc_file)
  return locs

# %%
def getListSegment(path_to_files):
  """
  input : str(path to files)
  output : list(list of segments)
  """
  segments = list()
  for path in glb.glob(path_to_files):
    segment = path.split('/')[-1].split('_')[6]
    if segment not in segments:
      segments.append(segment)
  return segments

# %% [markdown]
# ### Récupérations et transformations des données : les données à prédire

# %%
def getTestSetLocuteur(locuteur, path_input, img_rows=28, img_cols=28, num_classes=2):
  """
  input : str(id_locuteur), str(path to test files), int(image_rows), int(image_cols), int(number-classes)
  output : list(images), list(label)
  """
  x_test_loc = []
  y_test_loc = []
  fileNames_loc = []
  for path in glb.glob(path_input):
  #print(path)
    fileName = path.split('/')[-1]
  #print(fileName)
  #print(fileName.split('_'))
    if locuteur in fileName: 
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_test_loc.append(x)
      y_test_loc.append(y)
      fileNames_loc.append(fileName)

  #print(len(x_test_loc))
  x_test_loc = np.array(x_test_loc)
  x_test_loc = x_test_loc.reshape(-1, x_test_loc.shape[1],x_test_loc.shape[2],1)
  x_test_loc = x_test_loc.astype('float32')
  x_test_loc /= 255. 

  y_test_loc = np.array(y_test_loc)
  y_test_loc = to_categorical(y_test_loc, num_classes, dtype='float32')
  return x_test_loc, y_test_loc, fileNames_loc

# %%
def getTestSetTroncons(tier, path_input, img_rows=28, img_cols=28, num_classes=2):
  """
  input : int(tier), str(path to test files), int(image_rows), int(image_cols), int(number-classes)
  output : list(images), list(label)
  """
  x_test_loc = []
  y_test_loc = []
  for path in glb.glob(path_input):
  #print(path)
    fileName = path.split('/')[-1]
  #print(fileName)
  #print(fileName.split('_'))
    tier = str(tier)
    if tier == fileName.split("_")[-1][0]:
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_test_loc.append(x)
      y_test_loc.append(y)

  #print(len(x_test_loc))
  x_test_loc = np.array(x_test_loc)
  x_test_loc = x_test_loc.reshape(-1, x_test_loc.shape[1],x_test_loc.shape[2],1)
  x_test_loc = x_test_loc.astype('float32')
  x_test_loc /= 255. 

  y_test_loc = np.array(y_test_loc)
  y_test_loc = to_categorical(y_test_loc, num_classes, dtype='float32')
  return x_test_loc, y_test_loc

# %%
def getTestSetSegment(segment, path_input, img_rows=28, img_cols=28, num_classes=2):
  """
  input : str(segment), str(path to test files), int(image_rows), int(image_cols), int(number-classes)
  output : list(images), list(label)
  """
  x_test_seg = []
  y_test_seg = []
  for path in glb.glob(path_input):
  #print(path)
    fileName = path.split('/')[-1]
  #print(fileName)
  #print(fileName.split('_'))
    if segment in fileName.split('_')[6]: 
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_test_seg.append(x)
      y_test_seg.append(y)

  #print(len(x_test_loc))
  x_test_seg = np.array(x_test_seg)
  x_test_seg = x_test_seg.reshape(-1, x_test_seg.shape[1],x_test_seg.shape[2],1)
  x_test_seg = x_test_seg.astype('float32')
  x_test_seg /= 255. 

  y_test_seg = np.array(y_test_seg)
  y_test_seg = to_categorical(y_test_seg, num_classes, dtype='float32')
  return x_test_seg, y_test_seg

# %% [markdown]
# ## Initiation de la prédiction d'un modèle

# %%
def testLocuteur(model, path_output="drive/Shareddrives/ReseauNeurones/resume_resultats/all_score_loc.csv", path_input="drive/Shareddrives/ReseauNeurones/images/test/*/*"):
  """
  input : str(chemin vers les fichiers de test), str(chemin pour sauvegarder le fichier csv)
  output : df[col : scores, line : locuteur]
  """
  resultat = dict()
  locs = getListLocuteur(path_input)

  for locuteur in locs:
    x_test_loc, y_test_loc, fileNames = getTestSetLocuteur(locuteur, path_input)
    Y_test = np.argmax(y_test_loc, axis=1) # Convert one-hot to index
    y_pred = model.predict_classes(x_test_loc)
    resultat[locuteur] = getScoreLocuteur(classification_report(Y_test, y_pred))
    
    proba = model.predict(x_test_loc)
    print(proba)
    result_proba = dict()
    for i in range(len(proba)):
      score = dict()
      score["son"] = fileNames[i].split('_')[6]
      score["tier"] = fileNames[i].split('_')[-1][0]
      score["contexte_gauche"] = fileNames[i].split('_')[8]
      score["contexte_droit"] = fileNames[i].split('_')[9]
      score["contextes"] = fileNames[i].split('_')[8] + "_" + fileNames[i].split('_')[9]
      score["temps_debut"] = fileNames[i].split('_')[-3]
      score["temps_fin"] = fileNames[i].split('_')[-2]
      score["proba_oral"] = f"{proba[i][0]:.6f}"
      score["proba_nasal"] = f"{proba[i][1]:.6f}"
      result_proba[i+1] = score
    sortie_locuteur = "drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/locuteurs/" + locuteur + ".csv"
    print(sortie_locuteur)
    getCSV(result_proba, sortie_locuteur)
  return getCSV(resultat, path_output)

# %%
def testTroncons(model, path_output="drive/Shareddrives/ReseauNeurones/resume_resultats/all_score_loc.csv", path_input="drive/Shareddrives/ReseauNeurones/images/test/*/*"):
  """
  input : str(chemin vers les fichiers de test), str(chemin pour sauvegarder le fichier csv)
  output : df[col : scores, line : tier]
  """
  resultat = dict()
  troncons = [1, 2, 3]

  for tier in troncons:
    x_test_loc, y_test_loc = getTestSetTroncons(tier, path_input)
    Y_test = np.argmax(y_test_loc, axis=1) # Convert one-hot to index
    y_pred = model.predict_classes(x_test_loc)
    resultat[tier] = getScoreLocuteur(classification_report(Y_test, y_pred))

  return getCSV(resultat, path_output)

# %%
def testSegment(model, path_output="drive/Shareddrives/ReseauNeurones/resume_resultats/all_score_loc.csv", path_input="drive/Shareddrives/ReseauNeurones/images/test/*/*"):
  """
  input : str(chemin vers les fichiers de test), str(chemin pour sauvegarder le fichier csv)
  output : df[col : scores, line : locuteur]
  """
  resultat = dict()
  segments = getListSegment(path_input)
  print(segments)
  for seg in segments:
    x_test_seg, y_test_seg = getTestSetSegment(seg, path_input)
    Y_test = np.argmax(y_test_seg, axis=1) # Convert one-hot to index
    y_pred = np.argmax(model.predict(x_test_seg), axis=-1)
    resultat[seg] = getScoreLocuteur(classification_report(Y_test, y_pred))

  return getCSV(resultat, path_output)

# %%
x_test_troncons1 = list()
y_test_troncons1 = list()

x_test_troncons2 = list()
y_test_troncons2 = list()

x_test_troncons3 = list()
y_test_troncons3 = list()

resultat = dict()

for path in glb.glob("/content/drive/Shareddrives/ReseauNeurones/images_troncons/test/*/*"):
  #print(path)
    fileName = path.split('/')[-1]
  #print(fileName)
  #print(fileName.split('_'))
    if "1" == fileName.split("_")[-1][0]:
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_test_troncons1.append(x)
      y_test_troncons1.append(y)
    elif "2" == fileName.split("_")[-1][0]:
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_test_troncons2.append(x)
      y_test_troncons2.append(y)
    elif "3" == fileName.split("_")[-1][0]:
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_test_troncons3.append(x)
      y_test_troncons3.append(y)

  #print(len(x_test_loc))
x_test_troncons1 = np.array(x_test_troncons1)
x_test_troncons1 = x_test_troncons1.reshape(-1, x_test_troncons1.shape[1],x_test_troncons1.shape[2],1)
x_test_troncons1 = x_test_troncons1.astype('float32')
x_test_troncons1 /= 255. 

y_test_troncons1 = np.array(y_test_troncons1)
y_test_troncons1 = to_categorical(y_test_troncons1, 2, dtype='float32')

# 2
x_test_troncons2 = np.array(x_test_troncons2)
x_test_troncons2 = x_test_troncons2.reshape(-1, x_test_troncons2.shape[1],x_test_troncons2.shape[2],1)
x_test_troncons2 = x_test_troncons2.astype('float32')
x_test_troncons2 /= 255. 

y_test_troncons2 = np.array(y_test_troncons2)
y_test_troncons2 = to_categorical(y_test_troncons2, 2, dtype='float32')

# 3
x_test_troncons3 = np.array(x_test_troncons3)
x_test_troncons3 = x_test_troncons3.reshape(-1, x_test_troncons3.shape[1],x_test_troncons3.shape[2],1)
x_test_troncons3 = x_test_troncons3.astype('float32')
x_test_troncons3 /= 255. 

y_test_troncons3 = np.array(y_test_troncons3)
y_test_troncons3 = to_categorical(y_test_troncons3, 2, dtype='float32')

# %% [markdown]
# ## Récupérations et transformations des données pour construire un modèle

# %%
def getDataSet(path_input, img_rows=28, img_cols=28, num_classes=2):
  """
  input : str(id_locuteur), str(path to test files), int(image_rows), int(image_cols), int(number-classes)
  output : list(images), list(label)
  """
  x_data = []
  y_data = []
  fileNames = []
  
  for path in glb.glob(path_input) :
    label = path.split('/')[-2] #nasalité
    x = cv2.imread(path, 0).astype(np.uint8) 
    x = cv2.resize(x, (img_rows, img_cols)) 
    y = dicoLocs[label]
    x_data.append(x) 
    y_data.append(y)
    fileNames.append(path.split('/')[-1])

  x_data = np.array(x_data)
  x_data = x_data.reshape(-1, x_data.shape[1],x_data.shape[2],1)
  x_data = x_data.astype('float32')
  x_data /= 255. 

  y_data = np.array(y_data)
  y_data = to_categorical(y_data, num_classes, dtype='float32')
  
  return x_data, y_data, fileNames

# %% [markdown]
# ## Construction du classifieur

# %%
def keras_RN(x_train, y_train, x_test, y_test, activation, loss, optimizer, num_classes=2, batch_size=10, epochs=115, verbose=1):
  model = Sequential()
  model.add(Conv2D(32, kernel_size=(5,5),
                  activation=activation,
                  input_shape=(img_rows, img_cols, 1)))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(64, (5, 5), activation='tanh'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Flatten())
  model.add(Dense(num_classes, activation='softmax'))
  model.summary()
  es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
  mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)

  model.compile(loss=loss,
              optimizer=optimizer,
              metrics=['accuracy'])

  history = model.fit(x_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            verbose=verbose,
            validation_data=(x_test, y_test), 
            callbacks=[es,mc])

  score = model.evaluate(x_test, y_test, verbose=0)
  print('Test loss:', score[0])
  print('Test accuracy:', score[1])

  best_model=keras.models.load_model('best_model.h5')
  test_loss, test_acc = best_model.evaluate(x_test, y_test)
  val_loss_list=history.history['val_loss']
  best_val_loss_epoch=val_loss_list.index(min(val_loss_list))
  val_acc_list = history.history["val_accuracy"]
  best_val_acc_epoch = val_acc_list.index(max(val_acc_list))

  print("loss on test set : ", test_loss)
  print("accuracy on test set : ", test_acc)
  print("\nBest epoch for the val_loss is : ", best_val_loss_epoch)
  print("\nBest epoch for the val_acc is : ", best_val_acc_epoch)

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
  y_pred = model.predict_classes(x_test)
  print(classification_report(Y_test, y_pred))
  
  return model

# %% [markdown]
# Hyperparamètres pour le RN

# %%
dicoLocs = {'nasal':1, 'non_nasal':0}
labels = [l.split('/')[-1] for l in glb.glob('drive/Shareddrives/ReseauNeurones/images_troncons/train/*')]
img_rows, img_cols = 28, 28
batch_size = 10
epochs = 115
num_classes = len(labels)

# %%
print(dicoLocs)
print(labels)
# Out:
# {'nasal': 1, 'non_nasal': 0}
# ['nasal', 'non_nasal']

# %% [markdown]
# Les données - images et labels

# %%
x_train, y_train, fileNames_train = getDataSet('drive/Shareddrives/ReseauNeurones/images_troncons/train/*/*')
x_test, y_test, fileNames = getDataSet('drive/Shareddrives/ReseauNeurones/images_troncons/test/*/*')

# %%
print(len(x_train), len(x_test))
print(y_train)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 59400 14850
# [[0. 1.]
#  [0. 1.]
#  [0. 1.]
#  ...
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]]
# x_train shape: (59400, 28, 28, 1)
# x_test shape: (14850, 28, 28, 1)
# 59400 train samples
# 14850 test samples

# %% [markdown]
# # Exécution du modèle

# %% [markdown]
# ##Entraînement 1
#     activation : tanh
#     model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

# %%
model = keras_RN(x_train, y_train, x_test, y_test, activation="tanh", loss="mean_squared_error", optimizer=optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 5940/5940 [==============================] - 30s 2ms/step - loss: 0.1663 - accuracy: 0.7511 - val_loss: 0.1124 - val_accuracy: 0.8514
# Epoch 2/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1125 - accuracy: 0.8498 - val_loss: 0.1115 - val_accuracy: 0.8490
# Epoch 3/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1085 - accuracy: 0.8564 - val_loss: 0.1104 - val_accuracy: 0.8511
# Epoch 4/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1069 - accuracy: 0.8582 - val_loss: 0.1091 - val_accuracy: 0.8541
# Epoch 5/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1069 - accuracy: 0.8583 - val_loss: 0.1075 - val_accuracy: 0.8554
# Epoch 6/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1059 - accuracy: 0.8587 - val_loss: 0.1086 - val_accuracy: 0.8558
# Epoch 7/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1044 - accuracy: 0.8625 - val_loss: 0.1063 - val_accuracy: 0.8580
# Epoch 8/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1027 - accuracy: 0.8647 - val_loss: 0.1072 - val_accuracy: 0.8580
# Epoch 9/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1039 - accuracy: 0.8618 - val_loss: 0.1064 - val_accuracy: 0.8578
# Epoch 10/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1019 - accuracy: 0.8647 - val_loss: 0.1052 - val_accuracy: 0.8584
# Epoch 11/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1036 - accuracy: 0.8611 - val_loss: 0.1074 - val_accuracy: 0.8557
# Epoch 12/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1019 - accuracy: 0.8644 - val_loss: 0.1057 - val_accuracy: 0.8583
# Epoch 13/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1010 - accuracy: 0.8657 - val_loss: 0.1063 - val_accuracy: 0.8579
# Epoch 14/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1000 - accuracy: 0.8672 - val_loss: 0.1064 - val_accuracy: 0.8573
# Epoch 15/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0987 - accuracy: 0.8695 - val_loss: 0.1060 - val_accuracy: 0.8582
# Epoch 16/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0987 - accuracy: 0.8698 - val_loss: 0.1067 - val_accuracy: 0.8581
# Epoch 17/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0993 - accuracy: 0.8685 - val_loss: 0.1059 - val_accuracy: 0.8593
# Epoch 18/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0990 - accuracy: 0.8706 - val_loss: 0.1079 - val_accuracy: 0.8576
# Epoch 19/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0996 - accuracy: 0.8691 - val_loss: 0.1054 - val_accuracy: 0.8579
# Epoch 20/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0980 - accuracy: 0.8707 - val_loss: 0.1057 - val_accuracy: 0.8596
# Epoch 21/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0984 - accuracy: 0.8716 - val_loss: 0.1061 - val_accuracy: 0.8569
# Epoch 22/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0971 - accuracy: 0.8726 - val_loss: 0.1063 - val_accuracy: 0.8583
# Epoch 23/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0981 - accuracy: 0.8721 - val_loss: 0.1065 - val_accuracy: 0.8593
# Epoch 24/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.
115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0882 - accuracy: 0.8868 - val_loss: 0.1103 - val_accuracy: 0.8545
# Epoch 56/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0876 - accuracy: 0.8874 - val_loss: 0.1098 - val_accuracy: 0.8569
# Epoch 57/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0898 - accuracy: 0.8846 - val_loss: 0.1105 - val_accuracy: 0.8558
# Epoch 58/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0863 - accuracy: 0.8907 - val_loss: 0.1141 - val_accuracy: 0.8515
# Epoch 59/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0874 - accuracy: 0.8891 - val_loss: 0.1129 - val_accuracy: 0.8521
# Epoch 60/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0882 - accuracy: 0.8880 - val_loss: 0.1133 - val_accuracy: 0.8539
# Epoch 61/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0850 - accuracy: 0.8929 - val_loss: 0.1141 - val_accuracy: 0.8501
# Epoch 62/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0884 - accuracy: 0.8876 - val_loss: 0.1125 - val_accuracy: 0.8546
# Epoch 63/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0853 - accuracy: 0.8918 - val_loss: 0.1131 - val_accuracy: 0.8502
# Epoch 64/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0860 - accuracy: 0.8914 - val_loss: 0.1125 - val_accuracy: 0.8511
# Epoch 65/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0867 - accuracy: 0.8906 - val_loss: 0.1129 - val_accuracy: 0.8518
# Epoch 66/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0858 - accuracy: 0.8924 - val_loss: 0.1152 - val_accuracy: 0.8500
# Epoch 67/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0845 - accuracy: 0.8937 - val_loss: 0.1130 - val_accuracy: 0.8523
# Epoch 68/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0844 - accuracy: 0.8940 - val_loss: 0.1156 - val_accuracy: 0.8489
# Epoch 69/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0843 - accuracy: 0.8938 - val_loss: 0.1139 - val_accuracy: 0.8510
# Epoch 70/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0830 - accuracy: 0.8959 - val_loss: 0.1130 - val_accuracy: 0.8534
# Epoch 71/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0837 - accuracy: 0.8952 - val_loss: 0.1132 - val_accuracy: 0.8528
# Epoch 72/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0838 - accuracy: 0.8958 - val_loss: 0.1148 - val_accuracy: 0.8524
# Epoch 73/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0839 - accuracy: 0.8942 - val_loss: 0.1171 - val_accuracy: 0.8474
# Epoch 74/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0827 - accuracy: 0.8966 - val_loss: 0.1122 - val_accuracy: 0.8579
# Epoch 00074: early stopping
# Test loss: 0.11221275478601456
# Test accuracy: 0.8579124808311462
# 465/465 [==============================] - 1s 2ms/step - loss: 0.1048 - accuracy: 0.8611
# loss on test set :  0.1048421561717987
# accuracy on test set :  0.8611447811126709
#
# Best epoch for the val_loss is :  23
#
# Best epoch for the val_acc is :  23
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86      7425
#            1       0.84      0.88      0.86      7425
#
#     accuracy                           0.86     14850
#    macro avg       0.86      0.86      0.86     14850
# weighted avg       0.86      0.86      0.86     14850

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model1')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model1/assets

# %%
model = tf.keras.models.load_model('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model1')

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %%
testLocuteur(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_loc_entrainement1.csv", "drive/Shareddrives/ReseauNeurones/images_troncons/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  [5.39631486e-01 4.60368514e-01]
#  [5.49285114e-01 4.50714856e-01]
#  [9.96846497e-01 3.15342331e-03]
#  [9.99616623e-01 3.83359409e-04]
#  [9.99889374e-01 1.10624998e-04]
#  [9.99660969e-01 3.39067512e-04]
#  [7.50643849e-01 2.49356136e-01]
#  [7.90592313e-01 2.09407702e-01]
#  [9.99712408e-01 2.87604431e-04]
#  [7.14149892e-01 2.85850108e-01]
#  [9.99261081e-01 7.38909643e-04]
#  [9.99843717e-01 1.56270427e-04]
#  [9.99823749e-01 1.76236921e-04]
#  [9.90196168e-01 9.80386324e-03]
#  [8.74544501e-01 1.25455543e-01]
#  [3.07683140e-01 6.92316830e-01]
#  [9.97491956e-01 2.50805402e-03]
#  [9.99769390e-01 2.30558144e-04]
#  [9.99573648e-01 4.26312065e-04]
#  [1.58607617e-01 8.41392398e-01]
#  

#  [1.58607617e-01 8.41392398e-01]
#  [9.99837995e-01 1.61929172e-04]
#  [9.85283971e-01 1.47161027e-02]
#  [1.58607617e-01 8.41392398e-01]
#  [1.58607617e-01 8.41392398e-01]
#  [9.97540712e-01 2.45934771e-03]
#  [4.63631809e-01 5.36368132e-01]
#  [9.92051363e-01 7.94856343e-03]
#  [9.99951482e-01 4.84592820e-05]
#  [9.99917626e-01 8.23821465e-05]
#  [1.58607617e-01 8.41392398e-01]
#  [9.91845667e-01 8.15429725e-03]
#  [9.98810053e-01 1.19001488e-03]
#  [9.99815762e-01 1.84231627e-04]
#  [9.98449802e-01 1.55013031e-03]
#  [9.98931468e-01 1.06857962e-03]
#  [9.73306775e-01 2.66932361e-02]
#  [9.97204363e-01 2.79557006e-03]
#  [9.99925733e-01 7.42402990e-05]
#  [9.99475062e-01 5.25019539e-04]
#  [8.95904183e-01 1.04095779e-01]
#  [9.94165778e-01 5.83415478e-03]
#  [9.99895453e-01 1.04502105e-04]
#  [9.84020770e-01 1.59792099e-02]
#  [9.98742402e-01 1.25761179e-03]
#  [1.58607617e-01 8.41392398e-01]
#  [9.99516606e-01 4.83357202e-04]
#  [9.83078659e-01 1.69213451e-02]
#  [9.99953270e-01 4.67833997e-05]
#  [9.95224178e-01 4.77585709e-03]
#  [9.00712848e-01 9.92871672e-02]
#  [9.99870777e-01 1.29196589e-04]
#  [1.58607587e-01 8.41392398e-01]
#  [1.58607587e-01 8.41392398e-01]
#  [9.81414616e-01 1.85854360e-02]
#  [8.76942754e-01 1.23057298e-01]]
# drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/locuteurs/03_12_07_nb1_2_16.csv

# %%
testSegment(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_seg_entrainement1.csv", "/content/drive/Shareddrives/ReseauNeurones/images_troncons/test/*/*")
# Out:
# ['A', 'a']
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
Y_test = np.argmax(y_test_troncons1, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons1)
resultat["1"] = getScoreLocuteur(classification_report(Y_test, y_pred))

# 2
Y_test = np.argmax(y_test_troncons2, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons2)
resultat["2"] = getScoreLocuteur(classification_report(Y_test, y_pred))

# 3
Y_test = np.argmax(y_test_troncons3, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons3)
resultat["3"] = getScoreLocuteur(classification_report(Y_test, y_pred))

getCSV(resultat, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_tier_entrainement1.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
proba = model.predict(x_test)
print(proba)
# Out:
# [[0.08674593 0.91325414]
#  [0.15860762 0.8413924 ]
#  [0.02812343 0.9718766 ]
#  ...
#  [0.99530137 0.00469859]
#  [0.44710708 0.552893  ]
#  [0.998481   0.00151908]]

# %%
print(proba[0])
for i in proba[0]:
  print(f"{i:.6f}")
# Out:
# [0.08674593 0.91325414]
# 0.086746
# 0.913254

# %%
resultat = dict()

for i in range(len(proba)):
  score = dict()
  score["son"] = fileNames[i].split('_')[6]
  score["tier"] = fileNames[i].split('_')[-1][0]
  score["contexte_gauche"] = fileNames[i].split('_')[8]
  score["contexte_droit"] = fileNames[i].split('_')[9]
  score["contextes"] = fileNames[i].split('_')[8] + "_" + fileNames[i].split('_')[9]
  score["temps_debut"] = fileNames[i].split('_')[-3]
  score["temps_fin"] = fileNames[i].split('_')[-2]
  score["proba_oral"] = f"{proba[i][0]:.6f}"
  score["proba_nasal"] = f"{proba[i][1]:.6f}"
  resultat[i+1] = score


getCSV(resultat, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_context_entrainement1.csv")

# %%
resultat = dict()

# %% [markdown]
# # Entraînement en retirant 5 locuteurs

# %%
path_input = 'drive/Shareddrives/ReseauNeurones/images_troncons/train/*/*'
path_test = 'drive/Shareddrives/ReseauNeurones/images_troncons/train/*'

locs = getListLocuteur(path_input)
locs_40 = locs[5:]
locs_5 = locs[:5]
print(locs_5)
print(locs_40)
x_train_locs_40, y_train_locs_40 = [], []
x_test_locs_5, y_test_locs_5 = [], []
fileNames = []
fileNames_test = []

for locuteur in locs_40:
  for path in glb.glob(path_input):
    if locuteur in path.split('/')[-1]:
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_train_locs_40.append(x)
      y_train_locs_40.append(y)
      fileNames.append(path.split('/')[-1])

#print(len(x_test_loc))
x_train_locs_40 = np.array(x_train_locs_40)
x_train_locs_40 = x_train_locs_40.reshape(-1, x_train_locs_40.shape[1],x_train_locs_40.shape[2],1)
x_train_locs_40 = x_train_locs_40.astype('float32')
x_train_locs_40 /= 255. 

y_train_locs_40 = np.array(y_train_locs_40)
y_train_locs_40 = to_categorical(y_train_locs_40, num_classes, dtype='float32')

for locuteur in locs_5:
  for path in glb.glob(path_test):
    for path_to_file in glb.glob(path + "/*"):
      if locuteur in path_to_file.split('/')[-1]:
        label = path_to_file.split('/')[-2]
        x = cv2.imread(path_to_file, 0).astype(np.uint8)
        x = cv2.resize(x, (img_rows, img_cols))
        y = dicoLocs[label]
        x_test_locs_5.append(x)
        y_test_locs_5.append(y)
        fileNames_test.append(path_to_file.split('/')[-1])

#print(len(x_test_loc))
x_test_locs_5 = np.array(x_test_locs_5)
x_test_locs_5 = x_test_locs_5.reshape(-1, x_test_locs_5.shape[1],x_test_locs_5.shape[2],1)
x_test_locs_5 = x_test_locs_5.astype('float32')
x_test_locs_5 /= 255. 

y_test_locs_5 = np.array(y_test_locs_5)
y_test_locs_5 = to_categorical(y_test_locs_5, num_classes, dtype='float32')


print(len(x_train_locs_40), len(y_train_locs_40), len(fileNames))
print(len(x_test_locs_5), len(y_test_locs_5), len(fileNames_test))
# Out:
# ['30_11_07_nb1_1_16', '30_11_07_nb1_2_16', '29_11_07_nb2_1_16', '29_11_07_nb2_2_16', '29_11_07_nb1_2_16']
# ['28_11_07_nb2_1_16', '28_11_07_nb2_2_16', '28_11_07_nb1_2_16', '27_11_07_nb2_2_16', '28_11_07_nb1_1_16', '27_11_07_nb2_1_16', '27_11_07_nb1_1_16', '27_11_07_nb1_2_16', '26_11_07_nb3_2_16', '26_11_07_nb2_2_16', '26_11_07_nb3_1_16', '26_11_07_nb2_1_16', '26_11_07_nb1_1_16', '26_11_07_nb1_2_16', '23_11_07_nb1_2_16', '22_11_07_nb2_2_16', '23_11_07_nb1_1_16', '22_11_07_nb2_1_16', '22_11_07_nb1_1_16', '22_11_07_nb1_2_16', '20_11_07_nb1_2_16', '16_11_07_nb2_2_16', '20_11_07_nb1_1_16', '16_11_07_nb2_1_16', '16_11_07_nb1_1_16', '16_11_07_nb1_2_16', '14_11_07_nb2_2_16', '14_11_07_nb1_2_16', '14_11_07_nb2_1_16', '14_11_07_nb1_1_16', '05_12_07_nb1_1_16', '05_12_07_nb1_2_16', '04_12_07_nb3_2_16', '04_12_07_nb2_2_16', '04_12_07_nb3_1_16', '04_12_07_nb2_1_16', '04_12_07_nb1_1_16', '04_12_07_nb1_2_16', '03_12_07_nb1_2_16', '03_12_07_nb1_1_16']
# 52800 52800 52800
# 6600 6600 6600

# %%
model = keras_RN(x_train_locs_40, y_train_locs_40, x_test_locs_5, y_test_locs_5, activation="tanh", loss="mean_squared_error", optimizer=optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True))
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1688 - accuracy: 0.7450 - val_loss: 0.1213 - val_accuracy: 0.8371
# Epoch 2/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1109 - accuracy: 0.8510 - val_loss: 0.1203 - val_accuracy: 0.8388
# Epoch 3/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1064 - accuracy: 0.8586 - val_loss: 0.1199 - val_accuracy: 0.8417
# Epoch 4/115
# 5280/5280 [==============================] - 12s 2ms/step - loss: 0.1050 - accuracy: 0.8595 - val_loss: 0.1213 - val_accuracy: 0.8373
# Epoch 5/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.
115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0841 - accuracy: 0.8938 - val_loss: 0.1247 - val_accuracy: 0.8411
# Epoch 65/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0841 - accuracy: 0.8929 - val_loss: 0.1279 - val_accuracy: 0.8379
# Epoch 66/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0837 - accuracy: 0.8945 - val_loss: 0.1270 - val_accuracy: 0.8362
# Epoch 67/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0823 - accuracy: 0.8959 - val_loss: 0.1324 - val_accuracy: 0.8323
# Epoch 00067: early stopping
# Test loss: 0.1324174851179123
# Test accuracy: 0.8322727084159851
# 207/207 [==============================] - 0s 2ms/step - loss: 0.1136 - accuracy: 0.8462
# loss on test set :  0.11357750743627548
# accuracy on test set :  0.8462121486663818
#
# Best epoch for the val_loss is :  16
#
# Best epoch for the val_acc is :  21
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84      3300
#            1       0.86      0.80      0.83      3300
#
#     accuracy                           0.83      6600
#    macro avg       0.83      0.83      0.83      6600
# weighted avg       0.83      0.83      0.83      6600

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_sans_5locs_model1')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_sans_5locs_model1/assets

# %%
predictions = model.predict(np.array(x_test_locs_5), batch_size=100)
ConfusionMatrix(np.array(y_test_locs_5.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %% [markdown]
# # Entraînement en retirant 5 locuteurs - 2

# %%
path_input = 'drive/Shareddrives/ReseauNeurones/images_troncons/train/*/*'
path_test = 'drive/Shareddrives/ReseauNeurones/images_troncons/train/*'

locs = getListLocuteur(path_input)
locs_40 = locs[10:] + locs[:5]
locs_5 = locs[5:10]
print(locs_5)
print(locs_40)
x_train_locs_40, y_train_locs_40 = [], []
x_test_locs_5, y_test_locs_5 = [], []
fileNames = []
fileNames_test = []

for locuteur in locs_40:
  for path in glb.glob(path_input):
    if locuteur in path.split('/')[-1]:
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_train_locs_40.append(x)
      y_train_locs_40.append(y)
      fileNames.append(path.split('/')[-1])

#print(len(x_test_loc))
x_train_locs_40 = np.array(x_train_locs_40)
x_train_locs_40 = x_train_locs_40.reshape(-1, x_train_locs_40.shape[1],x_train_locs_40.shape[2],1)
x_train_locs_40 = x_train_locs_40.astype('float32')
x_train_locs_40 /= 255. 

y_train_locs_40 = np.array(y_train_locs_40)
y_train_locs_40 = to_categorical(y_train_locs_40, num_classes, dtype='float32')

for locuteur in locs_5:
  for path in glb.glob(path_test):
    for path_to_file in glb.glob(path + "/*"):
      if locuteur in path_to_file.split('/')[-1]:
        label = path_to_file.split('/')[-2]
        x = cv2.imread(path_to_file, 0).astype(np.uint8)
        x = cv2.resize(x, (img_rows, img_cols))
        y = dicoLocs[label]
        x_test_locs_5.append(x)
        y_test_locs_5.append(y)
        fileNames_test.append(path_to_file.split('/')[-1])


#print(len(x_test_loc))
x_test_locs_5 = np.array(x_test_locs_5)
x_test_locs_5 = x_test_locs_5.reshape(-1, x_test_locs_5.shape[1],x_test_locs_5.shape[2],1)
x_test_locs_5 = x_test_locs_5.astype('float32')
x_test_locs_5 /= 255. 

y_test_locs_5 = np.array(y_test_locs_5)
y_test_locs_5 = to_categorical(y_test_locs_5, num_classes, dtype='float32')


print(len(x_train_locs_40), len(y_train_locs_40), len(fileNames))
print(len(x_test_locs_5), len(y_test_locs_5), len(fileNames_test))
# Out:
# ['28_11_07_nb2_1_16', '28_11_07_nb2_2_16', '28_11_07_nb1_2_16', '27_11_07_nb2_2_16', '28_11_07_nb1_1_16']
# ['27_11_07_nb2_1_16', '27_11_07_nb1_1_16', '27_11_07_nb1_2_16', '26_11_07_nb3_2_16', '26_11_07_nb2_2_16', '26_11_07_nb3_1_16', '26_11_07_nb2_1_16', '26_11_07_nb1_1_16', '26_11_07_nb1_2_16', '23_11_07_nb1_2_16', '22_11_07_nb2_2_16', '23_11_07_nb1_1_16', '22_11_07_nb2_1_16', '22_11_07_nb1_1_16', '22_11_07_nb1_2_16', '20_11_07_nb1_2_16', '16_11_07_nb2_2_16', '20_11_07_nb1_1_16', '16_11_07_nb2_1_16', '16_11_07_nb1_1_16', '16_11_07_nb1_2_16', '14_11_07_nb2_2_16', '14_11_07_nb1_2_16', '14_11_07_nb2_1_16', '14_11_07_nb1_1_16', '05_12_07_nb1_1_16', '05_12_07_nb1_2_16', '04_12_07_nb3_2_16', '04_12_07_nb2_2_16', '04_12_07_nb3_1_16', '04_12_07_nb2_1_16', '04_12_07_nb1_1_16', '04_12_07_nb1_2_16', '03_12_07_nb1_2_16', '03_12_07_nb1_1_16', '30_11_07_nb1_1_16', '30_11_07_nb1_2_16', '29_11_07_nb2_1_16', '29_11_07_nb2_2_16', '29_11_07_nb1_2_16']
# 52800 52800 52800
# 6600 6600 6600

# %%
model = keras_RN(x_train_locs_40, y_train_locs_40, x_test_locs_5, y_test_locs_5, activation="tanh", loss="mean_squared_error", optimizer=optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1676 - accuracy: 0.7489 - val_loss: 0.1193 - val_accuracy: 0.8402
# Epoch 2/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1109 - accuracy: 0.8518 - val_loss: 0.1107 - val_accuracy: 0.8529
# Epoch 3/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1092 - accuracy: 0.8554 - val_loss: 0.1096 - val_accuracy: 0.8524
# Epoch 4/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1065 - accuracy: 0.8579 - val_loss: 0.1141 - val_accuracy: 0.8447
# Epoch 5/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1073 - accuracy: 0.8575 - val_loss: 0.1082 - val_accuracy: 0.8562
# Epoch 6/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1041 - accuracy: 0.8609 - val_loss: 0.1149 - val_accuracy: 0.8476
# Epoch 7/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1039 - accuracy: 0.8608 - val_loss: 0.1158 - val_accuracy: 0.8471
# Epoch 8/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1044 - accuracy: 0.8611 - val_loss: 0.1087 - val_accuracy: 0.8556
# Epoch 9/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1006 - accuracy: 0.8671 - val_loss: 0.1083 - val_accuracy: 0.8539
# Epoch 10/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1013 - accuracy: 0.8657 - val_loss: 0.1064 - val_accuracy: 0.8573
# Epoch 11/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1005 - accuracy: 0.8676 - val_loss: 0.1061 - val_accuracy: 0.8565
# Epoch 12/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1014 - accuracy: 0.8647 - val_loss: 0.1088 - val_accuracy: 0.8544
# Epoch 13/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1008 - accuracy: 0.8651 - val_loss: 0.1096 - val_accuracy: 0.8523
# Epoch 14/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1027 - accuracy: 0.8629 - val_loss: 0.1114 - val_accuracy: 0.8464
# Epoch 15/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0994 - accuracy: 0.8685 - val_loss: 0.1096 - val_accuracy: 0.8512
# Epoch 16/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0992 - accuracy: 0.8694 - val_loss: 0.1073 - val_accuracy: 0.8568
# Epoch 17/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0973 - accuracy: 0.8719 - val_loss: 0.1094 - val_accuracy: 0.8503
# Epoch 18/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0983 - accuracy: 0.8707 - val_loss: 0.1081 - val_accuracy: 0.8541
# Epoch 19/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0973 - accuracy: 0.8718 - val_loss: 0.1086 - val_accuracy: 0.8530
# Epoch 20/115
# 5280/5280 [==============================] - 14s 3ms/step - loss: 0.0988 - accuracy: 0.8699 - val_loss: 0.1103 - val_accuracy: 0.8533
# Epoch 21/115
# 5280/5280 [==============================] - 14s 3ms/step - loss: 0.
115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0877 - accuracy: 0.8882 - val_loss: 0.1181 - val_accuracy: 0.8433
# Epoch 52/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0871 - accuracy: 0.8886 - val_loss: 0.1136 - val_accuracy: 0.8491
# Epoch 53/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0890 - accuracy: 0.8879 - val_loss: 0.1093 - val_accuracy: 0.8529
# Epoch 54/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0868 - accuracy: 0.8907 - val_loss: 0.1185 - val_accuracy: 0.8408
# Epoch 55/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0865 - accuracy: 0.8905 - val_loss: 0.1110 - val_accuracy: 0.8514
# Epoch 56/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0874 - accuracy: 0.8885 - val_loss: 0.1171 - val_accuracy: 0.8430
# Epoch 57/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0868 - accuracy: 0.8914 - val_loss: 0.1120 - val_accuracy: 0.8515
# Epoch 58/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0869 - accuracy: 0.8885 - val_loss: 0.1137 - val_accuracy: 0.8489
# Epoch 59/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0856 - accuracy: 0.8918 - val_loss: 0.1183 - val_accuracy: 0.8430
# Epoch 60/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0850 - accuracy: 0.8932 - val_loss: 0.1152 - val_accuracy: 0.8445
# Epoch 61/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0835 - accuracy: 0.8951 - val_loss: 0.1156 - val_accuracy: 0.8480
# Epoch 00061: early stopping
# Test loss: 0.11558623611927032
# Test accuracy: 0.8480303287506104
# 207/207 [==============================] - 1s 2ms/step - loss: 0.1061 - accuracy: 0.8565
# loss on test set :  0.10611768066883087
# accuracy on test set :  0.8565151691436768
#
# Best epoch for the val_loss is :  10
#
# Best epoch for the val_acc is :  9
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84      3300
#            1       0.82      0.89      0.85      3300
#
#     accuracy                           0.85      6600
#    macro avg       0.85      0.85      0.85      6600
# weighted avg       0.85      0.85      0.85      6600

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_sans_5locs_model1-2')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_sans_5locs_model1-2/assets

# %%
predictions = model.predict(np.array(x_test_locs_5), batch_size=100)
ConfusionMatrix(np.array(y_test_locs_5.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %%
print(len(x_train_locs_40), len(y_train_locs_40), len(fileNames))
print(len(x_test_locs_5), len(y_test_locs_5), len(fileNames_test))
# Out:
# 52800 52800 52800
# 6600 6600 6600

# %%
locs_40 = locs[20:] + locs[:15]
locs_5 = locs[15:20]

# %% [markdown]
# # Entraînement en retirant 5 locuteurs - 3

# %%
path_input = 'drive/Shareddrives/ReseauNeurones/images_troncons/train/*/*'
path_test = 'drive/Shareddrives/ReseauNeurones/images_troncons/train/*'

locs = getListLocuteur(path_input)
locs_40 = locs[20:] + locs[:15]
locs_5 = locs[15:20]
print(locs_5)
print(locs_40)
x_train_locs_40, y_train_locs_40 = [], []
x_test_locs_5, y_test_locs_5 = [], []
fileNames = []
fileNames_test = []

for locuteur in locs_40:
  for path in glb.glob(path_input):
    if locuteur in path.split('/')[-1]:
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_train_locs_40.append(x)
      y_train_locs_40.append(y)
      fileNames.append(path.split('/')[-1])

#print(len(x_test_loc))
x_train_locs_40 = np.array(x_train_locs_40)
x_train_locs_40 = x_train_locs_40.reshape(-1, x_train_locs_40.shape[1],x_train_locs_40.shape[2],1)
x_train_locs_40 = x_train_locs_40.astype('float32')
x_train_locs_40 /= 255. 

y_train_locs_40 = np.array(y_train_locs_40)
y_train_locs_40 = to_categorical(y_train_locs_40, num_classes, dtype='float32')

for locuteur in locs_5:
  for path in glb.glob(path_test):
    for path_to_file in glb.glob(path + "/*"):
      if locuteur in path_to_file.split('/')[-1]:
        label = path_to_file.split('/')[-2]
        x = cv2.imread(path_to_file, 0).astype(np.uint8)
        x = cv2.resize(x, (img_rows, img_cols))
        y = dicoLocs[label]
        x_test_locs_5.append(x)
        y_test_locs_5.append(y)
        fileNames_test.append(path_to_file.split('/')[-1])
#print(len(x_test_loc))
x_test_locs_5 = np.array(x_test_locs_5)
x_test_locs_5 = x_test_locs_5.reshape(-1, x_test_locs_5.shape[1],x_test_locs_5.shape[2],1)
x_test_locs_5 = x_test_locs_5.astype('float32')
x_test_locs_5 /= 255. 

y_test_locs_5 = np.array(y_test_locs_5)
y_test_locs_5 = to_categorical(y_test_locs_5, num_classes, dtype='float32')


print(len(x_train_locs_40), len(y_train_locs_40), len(fileNames))
print(len(x_test_locs_5), len(y_test_locs_5), len(fileNames_test))
# Out:
# ['26_11_07_nb3_1_16', '26_11_07_nb2_1_16', '26_11_07_nb1_1_16', '26_11_07_nb1_2_16', '23_11_07_nb1_2_16']
# ['22_11_07_nb2_2_16', '23_11_07_nb1_1_16', '22_11_07_nb2_1_16', '22_11_07_nb1_1_16', '22_11_07_nb1_2_16', '20_11_07_nb1_2_16', '16_11_07_nb2_2_16', '20_11_07_nb1_1_16', '16_11_07_nb2_1_16', '16_11_07_nb1_1_16', '16_11_07_nb1_2_16', '14_11_07_nb2_2_16', '14_11_07_nb1_2_16', '14_11_07_nb2_1_16', '14_11_07_nb1_1_16', '05_12_07_nb1_1_16', '05_12_07_nb1_2_16', '04_12_07_nb3_2_16', '04_12_07_nb2_2_16', '04_12_07_nb3_1_16', '04_12_07_nb2_1_16', '04_12_07_nb1_1_16', '04_12_07_nb1_2_16', '03_12_07_nb1_2_16', '03_12_07_nb1_1_16', '30_11_07_nb1_1_16', '30_11_07_nb1_2_16', '29_11_07_nb2_1_16', '29_11_07_nb2_2_16', '29_11_07_nb1_2_16', '28_11_07_nb2_1_16', '28_11_07_nb2_2_16', '28_11_07_nb1_2_16', '27_11_07_nb2_2_16', '28_11_07_nb1_1_16', '27_11_07_nb2_1_16', '27_11_07_nb1_1_16', '27_11_07_nb1_2_16', '26_11_07_nb3_2_16', '26_11_07_nb2_2_16']
# 52800 52800 52800
# 6600 6600 6600

# %%
model = keras_RN(x_train_locs_40, y_train_locs_40, x_test_locs_5, y_test_locs_5, activation="tanh", loss="mean_squared_error", optimizer=optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1725 - accuracy: 0.7398 - val_loss: 0.1110 - val_accuracy: 0.8567
# Epoch 2/115
# 5280/5280 [==============================] - 14s 3ms/step - loss: 0.1138 - accuracy: 0.8481 - val_loss: 0.1058 - val_accuracy: 0.8591
# Epoch 3/115
# 5280/5280 [==============================] - 13s 3ms/step - loss: 0.1092 - accuracy: 0.8559 - val_loss: 0.1048 - val_accuracy: 0.8615
# Epoch 4/115
# 5280/5280 [==============================] - 13s 3ms/step - loss: 0.1089 - accuracy: 0.8553 - val_loss: 0.1042 - val_accuracy: 0.8612
# Epoch 5/115
# 5280/5280 [==============================] - 13s 3ms/step - loss: 0.1066 - accuracy: 0.8590 - val_loss: 0.1056 - val_accuracy: 0.8609
# Epoch 6/115
# 5280/5280 [==============================] - 13s 3ms/step - loss: 0.1065 - accuracy: 0.8581 - val_loss: 0.1024 - val_accuracy: 0.8648
# Epoch 7/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1051 - accuracy: 0.8599 - val_loss: 0.1016 - val_accuracy: 0.8644
# Epoch 8/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1028 - accuracy: 0.8633 - val_loss: 0.1082 - val_accuracy: 0.8544
# Epoch 9/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1022 - accuracy: 0.8637 - val_loss: 0.1003 - val_accuracy: 0.8656
# Epoch 10/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1019 - accuracy: 0.8648 - val_loss: 0.1032 - val_accuracy: 0.8598
# Epoch 11/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.
115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0917 - accuracy: 0.8824 - val_loss: 0.1089 - val_accuracy: 0.8594
# Epoch 44/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0921 - accuracy: 0.8819 - val_loss: 0.1080 - val_accuracy: 0.8565
# Epoch 45/115
# 5280/5280 [==============================] - 13s 3ms/step - loss: 0.0900 - accuracy: 0.8853 - val_loss: 0.1063 - val_accuracy: 0.8595
# Epoch 46/115
# 5280/5280 [==============================] - 13s 3ms/step - loss: 0.0885 - accuracy: 0.8853 - val_loss: 0.1094 - val_accuracy: 0.8539
# Epoch 47/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0910 - accuracy: 0.8845 - val_loss: 0.1067 - val_accuracy: 0.8600
# Epoch 48/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0897 - accuracy: 0.8844 - val_loss: 0.1056 - val_accuracy: 0.8612
# Epoch 49/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0899 - accuracy: 0.8835 - val_loss: 0.1091 - val_accuracy: 0.8544
# Epoch 50/115
# 5280/5280 [==============================] - 13s 3ms/step - loss: 0.0908 - accuracy: 0.8841 - val_loss: 0.1058 - val_accuracy: 0.8591
# Epoch 51/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0890 - accuracy: 0.8851 - val_loss: 0.1163 - val_accuracy: 0.8506
# Epoch 52/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0888 - accuracy: 0.8855 - val_loss: 0.1090 - val_accuracy: 0.8577
# Epoch 53/115
# 5280/5280 [==============================] - 13s 3ms/step - loss: 0.0886 - accuracy: 0.8871 - val_loss: 0.1080 - val_accuracy: 0.8571
# Epoch 54/115
# 5280/5280 [==============================] - 13s 3ms/step - loss: 0.0881 - accuracy: 0.8878 - val_loss: 0.1099 - val_accuracy: 0.8561
# Epoch 55/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0879 - accuracy: 0.8887 - val_loss: 0.1137 - val_accuracy: 0.8480
# Epoch 56/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0876 - accuracy: 0.8881 - val_loss: 0.1096 - val_accuracy: 0.8568
# Epoch 57/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0879 - accuracy: 0.8879 - val_loss: 0.1175 - val_accuracy: 0.8452
# Epoch 58/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0881 - accuracy: 0.8875 - val_loss: 0.1166 - val_accuracy: 0.8479
# Epoch 59/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0866 - accuracy: 0.8897 - val_loss: 0.1171 - val_accuracy: 0.8485
# Epoch 00059: early stopping
# Test loss: 0.11706040054559708
# Test accuracy: 0.8484848737716675
# 207/207 [==============================] - 1s 2ms/step - loss: 0.1003 - accuracy: 0.8656
# loss on test set :  0.10031077265739441
# accuracy on test set :  0.8656060695648193
#
# Best epoch for the val_loss is :  8
#
# Best epoch for the val_acc is :  35
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#               precision    recall  f1-score   support
#
#            0       0.92      0.77      0.83      3300
#            1       0.80      0.93      0.86      3300
#
#     accuracy                           0.85      6600
#    macro avg       0.86      0.85      0.85      6600
# weighted avg       0.86      0.85      0.85      6600

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_sans_5locs_model1-3')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_sans_5locs_model1-3/assets

# %%
predictions = model.predict(np.array(x_test_locs_5), batch_size=100)
ConfusionMatrix(np.array(y_test_locs_5.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %%
print(len(x_train_locs_40), len(y_train_locs_40), len(fileNames))
print(len(x_test_locs_5), len(y_test_locs_5), len(fileNames_test))
# Out:
# 52800 52800 52800
# 6600 6600 6600

# %% [markdown]
# # Entraînement en retirant 5 locuteurs - 4

# %%
path_input = 'drive/Shareddrives/ReseauNeurones/images_troncons/train/*/*'
path_test = 'drive/Shareddrives/ReseauNeurones/images_troncons/train/*'

locs = getListLocuteur(path_input)
locs_40 = locs[:40]
locs_5 = locs[40:]
print(locs_5)
print(locs_40)
x_train_locs_40, y_train_locs_40 = [], []
x_test_locs_5, y_test_locs_5 = [], []
fileNames = []
fileNames_test = []

for locuteur in locs_40:
  for path in glb.glob(path_input):
    if locuteur in path.split('/')[-1]:
      label = path.split('/')[-2]
      x = cv2.imread(path, 0).astype(np.uint8)
      x = cv2.resize(x, (img_rows, img_cols))
      y = dicoLocs[label]
      x_train_locs_40.append(x)
      y_train_locs_40.append(y)
      fileNames.append(path.split('/')[-1])

#print(len(x_test_loc))
x_train_locs_40 = np.array(x_train_locs_40)
x_train_locs_40 = x_train_locs_40.reshape(-1, x_train_locs_40.shape[1],x_train_locs_40.shape[2],1)
x_train_locs_40 = x_train_locs_40.astype('float32')
x_train_locs_40 /= 255. 

y_train_locs_40 = np.array(y_train_locs_40)
y_train_locs_40 = to_categorical(y_train_locs_40, num_classes, dtype='float32')

for locuteur in locs_5:
  for path in glb.glob(path_test):
    for path_to_file in glb.glob(path + "/*"):
      if locuteur in path_to_file.split('/')[-1]:
        label = path_to_file.split('/')[-2]
        x = cv2.imread(path_to_file, 0).astype(np.uint8)
        x = cv2.resize(x, (img_rows, img_cols))
        y = dicoLocs[label]
        x_test_locs_5.append(x)
        y_test_locs_5.append(y)
        fileNames_test.append(path_to_file.split('/')[-1])

#print(len(x_test_loc))
x_test_locs_5 = np.array(x_test_locs_5)
x_test_locs_5 = x_test_locs_5.reshape(-1, x_test_locs_5.shape[1],x_test_locs_5.shape[2],1)
x_test_locs_5 = x_test_locs_5.astype('float32')
x_test_locs_5 /= 255. 

y_test_locs_5 = np.array(y_test_locs_5)
y_test_locs_5 = to_categorical(y_test_locs_5, num_classes, dtype='float32')


print(len(x_train_locs_40), len(y_train_locs_40), len(fileNames))
print(len(x_test_locs_5), len(y_test_locs_5), len(fileNames_test))
# Out:
# ['04_12_07_nb2_1_16', '04_12_07_nb1_1_16', '04_12_07_nb1_2_16', '03_12_07_nb1_2_16', '03_12_07_nb1_1_16']
# ['30_11_07_nb1_1_16', '30_11_07_nb1_2_16', '29_11_07_nb2_1_16', '29_11_07_nb2_2_16', '29_11_07_nb1_2_16', '28_11_07_nb2_1_16', '28_11_07_nb2_2_16', '28_11_07_nb1_2_16', '27_11_07_nb2_2_16', '28_11_07_nb1_1_16', '27_11_07_nb2_1_16', '27_11_07_nb1_1_16', '27_11_07_nb1_2_16', '26_11_07_nb3_2_16', '26_11_07_nb2_2_16', '26_11_07_nb3_1_16', '26_11_07_nb2_1_16', '26_11_07_nb1_1_16', '26_11_07_nb1_2_16', '23_11_07_nb1_2_16', '22_11_07_nb2_2_16', '23_11_07_nb1_1_16', '22_11_07_nb2_1_16', '22_11_07_nb1_1_16', '22_11_07_nb1_2_16', '20_11_07_nb1_2_16', '16_11_07_nb2_2_16', '20_11_07_nb1_1_16', '16_11_07_nb2_1_16', '16_11_07_nb1_1_16', '16_11_07_nb1_2_16', '14_11_07_nb2_2_16', '14_11_07_nb1_2_16', '14_11_07_nb2_1_16', '14_11_07_nb1_1_16', '05_12_07_nb1_1_16', '05_12_07_nb1_2_16', '04_12_07_nb3_2_16', '04_12_07_nb2_2_16', '04_12_07_nb3_1_16']
# 52800 52800 52800
# 6600 6600 6600

# %%
model = keras_RN(x_train_locs_40, y_train_locs_40, x_test_locs_5, y_test_locs_5, activation="tanh", loss="mean_squared_error", optimizer=optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1735 - accuracy: 0.7399 - val_loss: 0.1150 - val_accuracy: 0.8462
# Epoch 2/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1094 - accuracy: 0.8542 - val_loss: 0.1141 - val_accuracy: 0.8477
# Epoch 3/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1064 - accuracy: 0.8584 - val_loss: 0.1166 - val_accuracy: 0.8423
# Epoch 4/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1066 - accuracy: 0.8589 - val_loss: 0.1103 - val_accuracy: 0.8518
# Epoch 5/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1057 - accuracy: 0.8591 - val_loss: 0.1163 - val_accuracy: 0.8373
# Epoch 6/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1043 - accuracy: 0.8609 - val_loss: 0.1114 - val_accuracy: 0.8494
# Epoch 7/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1045 - accuracy: 0.8616 - val_loss: 0.1068 - val_accuracy: 0.8573
# Epoch 8/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1026 - accuracy: 0.8640 - val_loss: 0.1100 - val_accuracy: 0.8514
# Epoch 9/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1027 - accuracy: 0.8654 - val_loss: 0.1067 - val_accuracy: 0.8592
# Epoch 10/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0998 - accuracy: 0.8687 - val_loss: 0.1110 - val_accuracy: 0.8512
# Epoch 11/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1035 - accuracy: 0.8634 - val_loss: 0.1124 - val_accuracy: 0.8465
# Epoch 12/115
# 5280/5280 [==============================] - 13s 3ms/step - loss: 0.1003 - accuracy: 0.8674 - val_loss: 0.1069 - val_accuracy: 0.8585
# Epoch 13/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1012 - accuracy: 0.8670 - val_loss: 0.1050 - val_accuracy: 0.8618
# Epoch 14/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.1000 - accuracy: 0.8675 - val_loss: 0.1059 - val_accuracy: 0.8577
# Epoch 15/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0985 - accuracy: 0.8698 - val_loss: 0.1094 - val_accuracy: 0.8542
# Epoch 16/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0985 - accuracy: 0.8707 - val_loss: 0.1089 - val_accuracy: 0.8527
# Epoch 17/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0992 - accuracy: 0.8709 - val_loss: 0.1062 - val_accuracy: 0.8565
# Epoch 18/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0990 - accuracy: 0.8705 - val_loss: 0.1073 - val_accuracy: 0.8567
# Epoch 19/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0977 - accuracy: 0.8716 - val_loss: 0.1139 - val_accuracy: 0.8498
# Epoch 20/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0948 - accuracy: 0.8765 - val_loss: 0.1103 - val_accuracy: 0.8498
# Epoch 21/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0973 - accuracy: 0.8731 - val_loss: 0.1095 - val_accuracy: 0.8536
# Epoch 22/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0965 - accuracy: 0.8733 - val_loss: 0.1099 - val_accuracy: 0.8526
# Epoch 23/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0964 - accuracy: 0.8743 - val_loss: 0.1100 - val_accuracy: 0.8512
# Epoch 24/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0955 - accuracy: 0.8764 - val_loss: 0.1119 - val_accuracy: 0.8500
# Epoch 25/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0961 - accuracy: 0.8732 - val_loss: 0.1123 - val_accuracy: 0.8494
# Epoch 26/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0943 - accuracy: 0.8774 - val_loss: 0.1088 - val_accuracy: 0.8538
# Epoch 27/115
# 5280/5280 [==============================] - 13s 3ms/step - loss: 0.0951 - accuracy: 0.8762 - val_loss: 0.1139 - val_accuracy: 0.8474
# Epoch 28/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0932 - accuracy: 0.8805 - val_loss: 0.1139 - val_accuracy: 0.8500
# Epoch 29/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0931 - accuracy: 0.8794 - val_loss: 0.1116 - val_accuracy: 0.8505
# Epoch 30/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0924 - accuracy: 0.8809 - val_loss: 0.1105 - val_accuracy: 0.8517
# Epoch 31/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0938 - accuracy: 0.8773 - val_loss: 0.1155 - val_accuracy: 0.8455
# Epoch 32/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0910 - accuracy: 0.8820 - val_loss: 0.1142 - val_accuracy: 0.8474
# Epoch 33/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0928 - accuracy: 0.8802 - val_loss: 0.1103 - val_accuracy: 0.8505
# Epoch 34/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0932 - accuracy: 0.8804 - val_loss: 0.1139 - val_accuracy: 0.8450
# Epoch 35/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.0919 - accuracy: 0.8814 - val_loss: 0.1127 - val_accuracy: 0.8524
# Epoch 36/115
# 5280/5280 [==============================] - 13s 2ms/step - loss: 0.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      3300
#            1       0.83      0.85      0.84      3300
#
#     accuracy                           0.84      6600
#    macro avg       0.84      0.84      0.84      6600
# weighted avg       0.84      0.84      0.84      6600

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_sans_5locs_model1-4')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_sans_5locs_model1-4/assets

# %%
predictions = model.predict(np.array(x_test_locs_5), batch_size=100)
ConfusionMatrix(np.array(y_test_locs_5.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %%
print(len(x_train_locs_40), len(y_train_locs_40), len(fileNames))
print(len(x_test_locs_5), len(y_test_locs_5), len(fileNames_test))
# Out:
# 52800 52800 52800
# 6600 6600 6600

# %% [markdown]
# ##Entraînement 2
#     activation : relu
#     model.compile(loss=keras.losses.categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])

# %%
model = keras_RN(x_train, y_train, x_test, y_test, activation="relu", loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adadelta())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6922 - accuracy: 0.5416 - val_loss: 0.6886 - val_accuracy: 0.7046
# Epoch 2/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6873 - accuracy: 0.6965 - val_loss: 0.6836 - val_accuracy: 0.7017
# Epoch 3/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6819 - accuracy: 0.7067 - val_loss: 0.6772 - val_accuracy: 0.7036
# Epoch 4/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.6750 - accuracy: 0.7082 - val_loss: 0.6686 - val_accuracy: 0.7094
# Epoch 5/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6651 - accuracy: 0.7131 - val_loss: 0.6566 - val_accuracy: 0.7077
# Epoch 6/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.6525 - accuracy: 0.7104 - val_loss: 0.6414 - val_accuracy: 0.7046
# Epoch 7/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6363 - accuracy: 0.7093 - val_loss: 0.6250 - val_accuracy: 0.7044
# Epoch 8/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.6202 - accuracy: 0.7081 - val_loss: 0.6090 - val_accuracy: 0.7031
# Epoch 9/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6040 - accuracy: 0.7076 - val_loss: 0.5945 - val_accuracy: 0.7050
# Epoch 10/115
# 5940/5940 [==============================] - 15s 3ms/step - loss: 0.5895 - accuracy: 0.7122 - val_loss: 0.5832 - val_accuracy: 0.7058
# Epoch 11/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5793 - accuracy: 0.7123 - val_loss: 0.5749 - val_accuracy: 0.7046
# Epoch 12/115
# 5940/5940 [==============================] - 15s 3ms/step - loss: 0.5707 - accuracy: 0.7120 - val_loss: 0.5695 - val_accuracy: 0.7049
# Epoch 13/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5667 - accuracy: 0.7123 - val_loss: 0.5655 - val_accuracy: 0.7061
# Epoch 14/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5637 - accuracy: 0.7120 - val_loss: 0.5629 - val_accuracy: 0.7067
# Epoch 15/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5583 - accuracy: 0.7162 - val_loss: 0.5611 - val_accuracy: 0.7078
# Epoch 16/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5591 - accuracy: 0.7143 - val_loss: 0.5598 - val_accuracy: 0.7088
# Epoch 17/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5568 - accuracy: 0.7168 - val_loss: 0.5586 - val_accuracy: 0.7086
# Epoch 18/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5557 - accuracy: 0.7157 - val_loss: 0.5576 - val_accuracy: 0.7088
# Epoch 19/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5598 - accuracy: 0.7108 - val_loss: 0.5568 - val_accuracy: 0.7088
# Epoch 20/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5546 - accuracy: 0.7150 - val_loss: 0.5558 - val_accuracy: 0.7096
# Epoch 21/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5517 - accuracy: 0.7184 - val_loss: 0.5549 - val_accuracy: 0.7112
# Epoch 22/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5515 - accuracy: 0.7189 - val_loss: 0.5542 - val_accuracy: 0.7106
# Epoch 23/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5502 - accuracy: 0.7194 - val_loss: 0.5534 - val_accuracy: 0.7112
# Epoch 24/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.
115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4189 - accuracy: 0.8199 - val_loss: 0.4229 - val_accuracy: 0.8158
# Test loss: 0.42294809222221375
# Test accuracy: 0.8158249258995056
# 465/465 [==============================] - 1s 2ms/step - loss: 0.4229 - accuracy: 0.8158
# loss on test set :  0.42294809222221375
# accuracy on test set :  0.8158249258995056
#
# Best epoch for the val_loss is :  114
#
# Best epoch for the val_acc is :  114
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82      7425
#            1       0.82      0.80      0.81      7425
#
#     accuracy                           0.82     14850
#    macro avg       0.82      0.82      0.82     14850
# weighted avg       0.82      0.82      0.82     14850

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model2')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model2/assets

# %%
model = tf.keras.models.load_model('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model2')

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %%
testLocuteur(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_loc_entrainement2.csv", "drive/Shareddrives/ReseauNeurones/images_troncons/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
testSegment(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_seg_entrainement2.csv", "/content/drive/Shareddrives/ReseauNeurones/images_troncons/test/*/*")
# Out:
# ['A', 'a']
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
Y_test = np.argmax(y_test_troncons1, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons1)
resultat["1"] = getScoreLocuteur(classification_report(Y_test, y_pred))

# 2
Y_test = np.argmax(y_test_troncons2, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons2)
resultat["2"] = getScoreLocuteur(classification_report(Y_test, y_pred))

# 3
Y_test = np.argmax(y_test_troncons3, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons3)
resultat["3"] = getScoreLocuteur(classification_report(Y_test, y_pred))

getCSV(resultat, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_tier_entrainement2.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
proba = model.predict(x_test)
print(proba)
# Out:
# [[0.4020516  0.5979484 ]
#  [0.16406354 0.8359364 ]
#  [0.21480118 0.7851988 ]
#  ...
#  [0.9382623  0.06173774]
#  [0.55772907 0.44227096]
#  [0.8951171  0.10488284]]

# %%
print(proba[0])
for i in proba[0]:
  print(f"{i:.6f}")
# Out:
# [0.4020516 0.5979484]
# 0.402052
# 0.597948

# %%
resultat = dict()

for i in range(len(proba)):
  score = dict()
  score["son"] = fileNames[i].split('_')[6]
  score["tier"] = fileNames[i].split('_')[-1][0]
  score["contexte_gauche"] = fileNames[i].split('_')[8]
  score["contexte_droit"] = fileNames[i].split('_')[9]
  score["contextes"] = fileNames[i].split('_')[8] + "_" + fileNames[i].split('_')[9]
  score["temps_debut"] = fileNames[i].split('_')[-3]
  score["temps_fin"] = fileNames[i].split('_')[-2]
  score["proba_oral"] = f"{proba[i][0]:.6f}"
  score["proba_nasal"] = f"{proba[i][1]:.6f}"
  resultat[i+1] = score


getCSV(resultat, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_context_entrainement2.csv")

# %%
resultat = dict()

# %% [markdown]
# ##Entraînement 3
#     activation : tanh
#     model.compile(loss=keras.losses.categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])

# %%
model = keras_RN(x_train, y_train, x_test, y_test, activation="tanh", loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adadelta())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6924 - accuracy: 0.5255 - val_loss: 0.6896 - val_accuracy: 0.5017
# Epoch 2/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6887 - accuracy: 0.6123 - val_loss: 0.6863 - val_accuracy: 0.6949
# Epoch 3/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.6853 - accuracy: 0.6487 - val_loss: 0.6826 - val_accuracy: 0.7025
# Epoch 4/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6813 - accuracy: 0.6768 - val_loss: 0.6774 - val_accuracy: 0.7036
# Epoch 5/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6758 - accuracy: 0.6934 - val_loss: 0.6708 - val_accuracy: 0.7009
# Epoch 6/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.6684 - accuracy: 0.7064 - val_loss: 0.6619 - val_accuracy: 0.7045
# Epoch 7/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6593 - accuracy: 0.7069 - val_loss: 0.6513 - val_accuracy: 0.7056
# Epoch 8/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6476 - accuracy: 0.7109 - val_loss: 0.6386 - val_accuracy: 0.7044
# Epoch 9/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.6350 - accuracy: 0.7101 - val_loss: 0.6250 - val_accuracy: 0.7040
# Epoch 10/115
# 5940/5940 [==============================] - 15s 3ms/step - loss: 0.6210 - accuracy: 0.7127 - val_loss: 0.6114 - val_accuracy: 0.7059
# Epoch 11/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.6069 - accuracy: 0.7113 - val_loss: 0.5990 - val_accuracy: 0.7063
# Epoch 12/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5958 - accuracy: 0.7132 - val_loss: 0.5881 - val_accuracy: 0.7053
# Epoch 13/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5839 - accuracy: 0.7128 - val_loss: 0.5797 - val_accuracy: 0.7050
# Epoch 14/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5786 - accuracy: 0.7116 - val_loss: 0.5736 - val_accuracy: 0.7065
# Epoch 15/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5720 - accuracy: 0.7125 - val_loss: 0.5693 - val_accuracy: 0.7065
# Epoch 16/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5673 - accuracy: 0.7120 - val_loss: 0.5664 - val_accuracy: 0.7065
# Epoch 17/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5638 - accuracy: 0.7139 - val_loss: 0.5644 - val_accuracy: 0.7064
# Epoch 18/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5635 - accuracy: 0.7127 - val_loss: 0.5632 - val_accuracy: 0.7072
# Epoch 19/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5632 - accuracy: 0.7130 - val_loss: 0.5618 - val_accuracy: 0.7069
# Epoch 20/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5572 - accuracy: 0.7168 - val_loss: 0.5608 - val_accuracy: 0.7084
# Epoch 21/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5602 - accuracy: 0.7140 - val_loss: 0.5603 - val_accuracy: 0.7071
# Epoch 22/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5562 - accuracy: 0.7168 - val_loss: 0.5592 - val_accuracy: 0.7092
# Epoch 23/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5574 - accuracy: 0.7160 - val_loss: 0.5585 - val_accuracy: 0.7096
# Epoch 24/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5580 - accuracy: 0.7151 - val_loss: 0.5580 - val_accuracy: 0.7103
# Epoch 25/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5548 - accuracy: 0.7173 - val_loss: 0.5571 - val_accuracy: 0.7101
# Epoch 26/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5541 - accuracy: 0.7186 - val_loss: 0.5564 - val_accuracy: 0.7104
# Epoch 27/115
# 5940/5940 [==============================] - 15s 3ms/step - loss: 0.5569 - accuracy: 0.7164 - val_loss: 0.5558 - val_accuracy: 0.7107
# Epoch 28/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5567 - accuracy: 0.7150 - val_loss: 0.5552 - val_accuracy: 0.7102
# Epoch 29/115
# 5940/5940 [==============================] - 15s 3ms/step - loss: 0.5528 - accuracy: 0.7188 - val_loss: 0.5545 - val_accuracy: 0.7114
# Epoch 30/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5527 - accuracy: 0.7206 - val_loss: 0.5540 - val_accuracy: 0.7131
# Epoch 31/115
# 5940/5940 [==============================] - 15s 3ms/step - loss: 0.5483 - accuracy: 0.7222 - val_loss: 0.5532 - val_accuracy: 0.7121
# Epoch 32/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5526 - accuracy: 0.7182 - val_loss: 0.5525 - val_accuracy: 0.7128
# Epoch 33/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5523 - accuracy: 0.7177 - val_loss: 0.5519 - val_accuracy: 0.7127
# Epoch 34/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5500 - accuracy: 0.7214 - val_loss: 0.5512 - val_accuracy: 0.7135
# Epoch 35/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5496 - accuracy: 0.7192 - val_loss: 0.5505 - val_accuracy: 0.7141
# Epoch 36/115
# 5940/5940 [==============================] - 15s 3ms/step - loss: 0.5484 - accuracy: 0.7206 - val_loss: 0.5498 - val_accuracy: 0.7139
# Epoch 37/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5491 - accuracy: 0.7198 - val_loss: 0.5496 - val_accuracy: 0.7178
# Epoch 38/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5503 - accuracy: 0.7205 - val_loss: 0.5485 - val_accuracy: 0.7145
# Epoch 39/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5425 - accuracy: 0.7262 - val_loss: 0.5477 - val_accuracy: 0.7151
# Epoch 40/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5457 - accuracy: 0.7214 - val_loss: 0.5469 - val_accuracy: 0.7172
# Epoch 41/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5461 - accuracy: 0.7219 - val_loss: 0.5463 - val_accuracy: 0.7162
# Epoch 42/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5416 - accuracy: 0.7239 - val_loss: 0.5455 - val_accuracy: 0.7165
# Epoch 43/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5446 - accuracy: 0.7235 - val_loss: 0.5446 - val_accuracy: 0.7193
# Epoch 44/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5441 - accuracy: 0.7222 - val_loss: 0.5440 - val_accuracy: 0.7180
# Epoch 45/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5422 - accuracy: 0.7251 - val_loss: 0.5431 - val_accuracy: 0.7199
# Epoch 46/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5459 - accuracy: 0.7218 - val_loss: 0.5425 - val_accuracy: 0.7238
# Epoch 47/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5386 - accuracy: 0.7279 - val_loss: 0.5414 - val_accuracy: 0.7209
# Epoch 48/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5394 - accuracy: 0.7265 - val_loss: 0.5407 - val_accuracy: 0.7211
# Epoch 49/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5409 - accuracy: 0.7257 - val_loss: 0.5403 - val_accuracy: 0.7195
# Epoch 50/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5410 - accuracy: 0.7250 - val_loss: 0.5387 - val_accuracy: 0.7248
# Epoch 51/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5407 - accuracy: 0.7248 - val_loss: 0.5378 - val_accuracy: 0.7271
# Epoch 52/115
# 5940/5940 [==============================] - 15s 3ms/step - loss: 0.5330 - accuracy: 0.7323 - val_loss: 0.5369 - val_accuracy: 0.7252
# Epoch 53/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5375 - accuracy: 0.7300 - val_loss: 0.5365 - val_accuracy: 0.7310
# Epoch 54/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5313 - accuracy: 0.7347 - val_loss: 0.5354 - val_accuracy: 0.7313
# Epoch 55/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5307 - accuracy: 0.7341 - val_loss: 0.5346 - val_accuracy: 0.7245
# Epoch 56/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5333 - accuracy: 0.7319 - val_loss: 0.5330 - val_accuracy: 0.7300
# Epoch 57/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5326 - accuracy: 0.7305 - val_loss: 0.5320 - val_accuracy: 0.7294
# Epoch 58/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5310 - accuracy: 0.7332 - val_loss: 0.5308 - val_accuracy: 0.7332
# Epoch 59/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5283 - accuracy: 0.7348 - val_loss: 0.5298 - val_accuracy: 0.7341
# Epoch 60/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5283 - accuracy: 0.7343 - val_loss: 0.5287 - val_accuracy: 0.7349
# Epoch 61/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5291 - accuracy: 0.7366 - val_loss: 0.5277 - val_accuracy: 0.7337
# Epoch 62/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5271 - accuracy: 0.7371 - val_loss: 0.5265 - val_accuracy: 0.7363
# Epoch 63/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5227 - accuracy: 0.7389 - val_loss: 0.5257 - val_accuracy: 0.7391
# Epoch 64/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5231 - accuracy: 0.7406 - val_loss: 0.5241 - val_accuracy: 0.7390
# Epoch 65/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5242 - accuracy: 0.7380 - val_loss: 0.5229 - val_accuracy: 0.7389
# Epoch 66/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5223 - accuracy: 0.7404 - val_loss: 0.5215 - val_accuracy: 0.7409
# Epoch 67/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5233 - accuracy: 0.7407 - val_loss: 0.5203 - val_accuracy: 0.7432
# Epoch 68/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5216 - accuracy: 0.7432 - val_loss: 0.5190 - val_accuracy: 0.7438
# Epoch 69/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.5161 - accuracy: 0.7470 - val_loss: 0.5178 - val_accuracy: 0.7470
# Epoch 70/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5172 - accuracy: 0.7471 - val_loss: 0.5165 - val_accuracy: 0.7494
# Epoch 71/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5164 - accuracy: 0.7469 - val_loss: 0.5150 - val_accuracy: 0.7446
# Epoch 72/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5120 - accuracy: 0.7504 - val_loss: 0.5134 - val_accuracy: 0.7485
# Epoch 73/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5147 - accuracy: 0.7488 - val_loss: 0.5119 - val_accuracy: 0.7488
# Epoch 74/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5114 - accuracy: 0.7509 - val_loss: 0.5109 - val_accuracy: 0.7467
# Epoch 75/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5115 - accuracy: 0.7513 - val_loss: 0.5088 - val_accuracy: 0.7539
# Epoch 76/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5018 - accuracy: 0.7582 - val_loss: 0.5072 - val_accuracy: 0.7560
# Epoch 77/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5058 - accuracy: 0.7583 - val_loss: 0.5058 - val_accuracy: 0.7528
# Epoch 78/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5047 - accuracy: 0.7574 - val_loss: 0.5039 - val_accuracy: 0.7562
# Epoch 79/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5035 - accuracy: 0.7580 - val_loss: 0.5022 - val_accuracy: 0.7582
# Epoch 80/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.5015 - accuracy: 0.7611 - val_loss: 0.5004 - val_accuracy: 0.7652
# Epoch 81/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4965 - accuracy: 0.7651 - val_loss: 0.4985 - val_accuracy: 0.7623
# Epoch 82/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4964 - accuracy: 0.7650 - val_loss: 0.4967 - val_accuracy: 0.7630
# Epoch 83/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4936 - accuracy: 0.7689 - val_loss: 0.4947 - val_accuracy: 0.7689
# Epoch 84/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4942 - accuracy: 0.7679 - val_loss: 0.4927 - val_accuracy: 0.7693
# Epoch 85/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4878 - accuracy: 0.7744 - val_loss: 0.4907 - val_accuracy: 0.7693
# Epoch 86/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4882 - accuracy: 0.7738 - val_loss: 0.4887 - val_accuracy: 0.7729
# Epoch 87/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4856 - accuracy: 0.7767 - val_loss: 0.4866 - val_accuracy: 0.7733
# Epoch 88/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4837 - accuracy: 0.7774 - val_loss: 0.4845 - val_accuracy: 0.7765
# Epoch 89/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4804 - accuracy: 0.7818 - val_loss: 0.4826 - val_accuracy: 0.7754
# Epoch 90/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4810 - accuracy: 0.7803 - val_loss: 0.4806 - val_accuracy: 0.7763
# Epoch 91/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4772 - accuracy: 0.7826 - val_loss: 0.4782 - val_accuracy: 0.7811
# Epoch 92/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4751 - accuracy: 0.7854 - val_loss: 0.4761 - val_accuracy: 0.7849
# Epoch 93/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4706 - accuracy: 0.7895 - val_loss: 0.4740 - val_accuracy: 0.7853
# Epoch 94/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4703 - accuracy: 0.7889 - val_loss: 0.4724 - val_accuracy: 0.7828
# Epoch 95/115
# 5940/5940 [==============================] - 15s 3ms/step - loss: 0.4663 - accuracy: 0.7931 - val_loss: 0.4697 - val_accuracy: 0.7902
# Epoch 96/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4617 - accuracy: 0.7946 - val_loss: 0.4677 - val_accuracy: 0.7902
# Epoch 97/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4634 - accuracy: 0.7933 - val_loss: 0.4659 - val_accuracy: 0.7898
# Epoch 98/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4653 - accuracy: 0.7925 - val_loss: 0.4640 - val_accuracy: 0.7904
# Epoch 99/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4624 - accuracy: 0.7936 - val_loss: 0.4613 - val_accuracy: 0.7952
# Epoch 100/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4584 - accuracy: 0.7986 - val_loss: 0.4594 - val_accuracy: 0.7980
# Epoch 101/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4574 - accuracy: 0.7991 - val_loss: 0.4572 - val_accuracy: 0.7981
# Epoch 102/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4535 - accuracy: 0.8009 - val_loss: 0.4552 - val_accuracy: 0.7991
# Epoch 103/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4511 - accuracy: 0.8028 - val_loss: 0.4532 - val_accuracy: 0.8003
# Epoch 104/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.4472 - accuracy: 0.8063 - val_loss: 0.4512 - val_accuracy: 0.8011
# Epoch 105/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4483 - accuracy: 0.8037 - val_loss: 0.4495 - val_accuracy: 0.8011
# Epoch 106/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4470 - accuracy: 0.8048 - val_loss: 0.4477 - val_accuracy: 0.8024
# Epoch 107/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4390 - accuracy: 0.8105 - val_loss: 0.4455 - val_accuracy: 0.8047
# Epoch 108/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4408 - accuracy: 0.8089 - val_loss: 0.4441 - val_accuracy: 0.8038
# Epoch 109/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4415 - accuracy: 0.8094 - val_loss: 0.4420 - val_accuracy: 0.8057
# Epoch 110/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4350 - accuracy: 0.8125 - val_loss: 0.4402 - val_accuracy: 0.8081
# Epoch 111/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4350 - accuracy: 0.8130 - val_loss: 0.4385 - val_accuracy: 0.8077
# Epoch 112/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4329 - accuracy: 0.8143 - val_loss: 0.4369 - val_accuracy: 0.8102
# Epoch 113/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4320 - accuracy: 0.8135 - val_loss: 0.4350 - val_accuracy: 0.8102
# Epoch 114/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4298 - accuracy: 0.8142 - val_loss: 0.4335 - val_accuracy: 0.8102
# Epoch 115/115
# 5940/5940 [==============================] - 15s 2ms/step - loss: 0.4291 - accuracy: 0.8144 - val_loss: 0.4319 - val_accuracy: 0.8117
# Test loss: 0.4318932592868805
# Test accuracy: 0.81171715259552
# 465/465 [==============================] - 1s 2ms/step - loss: 0.4319 - accuracy: 0.8117
# loss on test set :  0.4318932592868805
# accuracy on test set :  0.81171715259552
#
# Best epoch for the val_loss is :  114
#
# Best epoch for the val_acc is :  114
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81      7425
#            1       0.82      0.80      0.81      7425
#
#     accuracy                           0.81     14850
#    macro avg       0.81      0.81      0.81     14850
# weighted avg       0.81      0.81      0.81     14850

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model3')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model3/assets

# %%
model = tf.keras.models.load_model('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model3')

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %%
testLocuteur(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_loc_entrainement3.csv", "drive/Shareddrives/ReseauNeurones/images_troncons/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
testSegment(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_seg_entrainement3.csv", "/content/drive/Shareddrives/ReseauNeurones/images_troncons/test/*/*")
# Out:
# ['A', 'a']
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
Y_test = np.argmax(y_test_troncons1, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons1)
resultat["1"] = getScoreLocuteur(classification_report(Y_test, y_pred))

# 2
Y_test = np.argmax(y_test_troncons2, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons2)
resultat["2"] = getScoreLocuteur(classification_report(Y_test, y_pred))

# 3
Y_test = np.argmax(y_test_troncons3, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons3)
resultat["3"] = getScoreLocuteur(classification_report(Y_test, y_pred))

getCSV(resultat, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_tier_entrainement3.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
proba = model.predict(x_test)
print(proba)
# Out:
# [[0.3884827  0.61151725]
#  [0.16481514 0.8351849 ]
#  [0.20136075 0.79863924]
#  ...
#  [0.9147548  0.08524515]
#  [0.48297074 0.5170292 ]
#  [0.87755567 0.12244435]]

# %%
print(proba[0])
for i in proba[0]:
  print(f"{i:.6f}")
# Out:
# [0.3884827  0.61151725]
# 0.388483
# 0.611517

# %%
resultat = dict()

for i in range(len(proba)):
  score = dict()
  score["son"] = fileNames[i].split('_')[6]
  score["tier"] = fileNames[i].split('_')[-1][0]
  score["contexte_gauche"] = fileNames[i].split('_')[8]
  score["contexte_droit"] = fileNames[i].split('_')[9]
  score["contextes"] = fileNames[i].split('_')[8] + "_" + fileNames[i].split('_')[9]
  score["temps_debut"] = fileNames[i].split('_')[-3]
  score["temps_fin"] = fileNames[i].split('_')[-2]
  score["proba_oral"] = f"{proba[i][0]:.6f}"
  score["proba_nasal"] = f"{proba[i][1]:.6f}"
  resultat[i+1] = score


getCSV(resultat, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_context_entrainement3.csv")

# %%
resultat = dict()

# %% [markdown]
# ##Entraînement 4
#     activation : relu
#     model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

# %%
model = keras_RN(x_train, y_train, x_test, y_test, activation="relu", loss="mean_squared_error", optimizer=optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 54,146
# Trainable params: 54,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1679 - accuracy: 0.7539 - val_loss: 0.1184 - val_accuracy: 0.8382
# Epoch 2/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1129 - accuracy: 0.8502 - val_loss: 0.1126 - val_accuracy: 0.8498
# Epoch 3/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1101 - accuracy: 0.8523 - val_loss: 0.1118 - val_accuracy: 0.8512
# Epoch 4/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1104 - accuracy: 0.8534 - val_loss: 0.1121 - val_accuracy: 0.8500
# Epoch 5/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1064 - accuracy: 0.8582 - val_loss: 0.1082 - val_accuracy: 0.8554
# Epoch 6/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1070 - accuracy: 0.8580 - val_loss: 0.1084 - val_accuracy: 0.8552
# Epoch 7/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1073 - accuracy: 0.8582 - val_loss: 0.1073 - val_accuracy: 0.8557
# Epoch 8/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1056 - accuracy: 0.8608 - val_loss: 0.1083 - val_accuracy: 0.8560
# Epoch 9/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1038 - accuracy: 0.8636 - val_loss: 0.1078 - val_accuracy: 0.8566
# Epoch 10/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1063 - accuracy: 0.8577 - val_loss: 0.1111 - val_accuracy: 0.8493
# Epoch 11/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1066 - accuracy: 0.8596 - val_loss: 0.1110 - val_accuracy: 0.8526
# Epoch 12/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1042 - accuracy: 0.8630 - val_loss: 0.1087 - val_accuracy: 0.8548
# Epoch 13/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1046 - accuracy: 0.8619 - val_loss: 0.1148 - val_accuracy: 0.8498
# Epoch 14/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1028 - accuracy: 0.8637 - val_loss: 0.1092 - val_accuracy: 0.8562
# Epoch 15/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1048 - accuracy: 0.8606 - val_loss: 0.1078 - val_accuracy: 0.8574
# Epoch 16/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1049 - accuracy: 0.8621 - val_loss: 0.1088 - val_accuracy: 0.8538
# Epoch 17/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1044 - accuracy: 0.8617 - val_loss: 0.1086 - val_accuracy: 0.8543
# Epoch 18/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1038 - accuracy: 0.8632 - val_loss: 0.1086 - val_accuracy: 0.8562
# Epoch 19/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1039 - accuracy: 0.8632 - val_loss: 0.1087 - val_accuracy: 0.8560
# Epoch 20/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1012 - accuracy: 0.8673 - val_loss: 0.1093 - val_accuracy: 0.8531
# Epoch 21/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1040 - accuracy: 0.8633 - val_loss: 0.1077 - val_accuracy: 0.8570
# Epoch 22/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1023 - accuracy: 0.8670 - val_loss: 0.1078 - val_accuracy: 0.8572
# Epoch 23/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1032 - accuracy: 0.8644 - val_loss: 0.1069 - val_accuracy: 0.8568
# Epoch 24/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1027 - accuracy: 0.8654 - val_loss: 0.1097 - val_accuracy: 0.8531
# Epoch 25/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1036 - accuracy: 0.8625 - val_loss: 0.1071 - val_accuracy: 0.8583
# Epoch 26/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1024 - accuracy: 0.8654 - val_loss: 0.1092 - val_accuracy: 0.8554
# Epoch 27/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1011 - accuracy: 0.8668 - val_loss: 0.1095 - val_accuracy: 0.8537
# Epoch 28/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1038 - accuracy: 0.8622 - val_loss: 0.1082 - val_accuracy: 0.8570
# Epoch 29/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1031 - accuracy: 0.8641 - val_loss: 0.1106 - val_accuracy: 0.8529
# Epoch 30/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1016 - accuracy: 0.8670 - val_loss: 0.1095 - val_accuracy: 0.8552
# Epoch 31/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1031 - accuracy: 0.8644 - val_loss: 0.1122 - val_accuracy: 0.8502
# Epoch 32/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1008 - accuracy: 0.8677 - val_loss: 0.1090 - val_accuracy: 0.8544
# Epoch 33/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1015 - accuracy: 0.8662 - val_loss: 0.1078 - val_accuracy: 0.8567
# Epoch 34/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1013 - accuracy: 0.8671 - val_loss: 0.1075 - val_accuracy: 0.8559
# Epoch 35/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.0999 - accuracy: 0.8690 - val_loss: 0.1080 - val_accuracy: 0.8545
# Epoch 36/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.0995 - accuracy: 0.8697 - val_loss: 0.1074 - val_accuracy: 0.8566
# Epoch 37/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0998 - accuracy: 0.8691 - val_loss: 0.1083 - val_accuracy: 0.8568
# Epoch 38/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1023 - accuracy: 0.8649 - val_loss: 0.1084 - val_accuracy: 0.8554
# Epoch 39/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1020 - accuracy: 0.8665 - val_loss: 0.1082 - val_accuracy: 0.8561
# Epoch 40/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1008 - accuracy: 0.8673 - val_loss: 0.1083 - val_accuracy: 0.8557
# Epoch 41/115
# 5940/5940 [==============================] - 13s 2ms/step - loss: 0.1019 - accuracy: 0.8660 - val_loss: 0.1088 - val_accuracy: 0.8554
# Epoch 42/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1000 - accuracy: 0.8682 - val_loss: 0.1077 - val_accuracy: 0.8571
# Epoch 43/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1001 - accuracy: 0.8699 - val_loss: 0.1077 - val_accuracy: 0.8574
# Epoch 44/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0987 - accuracy: 0.8708 - val_loss: 0.1119 - val_accuracy: 0.8525
# Epoch 45/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1001 - accuracy: 0.8691 - val_loss: 0.1112 - val_accuracy: 0.8527
# Epoch 46/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0989 - accuracy: 0.8700 - val_loss: 0.1073 - val_accuracy: 0.8574
# Epoch 47/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0990 - accuracy: 0.8692 - val_loss: 0.1101 - val_accuracy: 0.8533
# Epoch 48/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1007 - accuracy: 0.8673 - val_loss: 0.1076 - val_accuracy: 0.8548
# Epoch 49/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1005 - accuracy: 0.8691 - val_loss: 0.1081 - val_accuracy: 0.8559
# Epoch 50/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1001 - accuracy: 0.8679 - val_loss: 0.1077 - val_accuracy: 0.8572
# Epoch 51/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1006 - accuracy: 0.8676 - val_loss: 0.1077 - val_accuracy: 0.8574
# Epoch 52/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1003 - accuracy: 0.8691 - val_loss: 0.1082 - val_accuracy: 0.8568
# Epoch 53/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0987 - accuracy: 0.8701 - val_loss: 0.1081 - val_accuracy: 0.8572
# Epoch 54/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0997 - accuracy: 0.8693 - val_loss: 0.1085 - val_accuracy: 0.8556
# Epoch 55/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1000 - accuracy: 0.8690 - val_loss: 0.1089 - val_accuracy: 0.8527
# Epoch 56/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0982 - accuracy: 0.8706 - val_loss: 0.1087 - val_accuracy: 0.8568
# Epoch 57/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0981 - accuracy: 0.8711 - val_loss: 0.1094 - val_accuracy: 0.8543
# Epoch 58/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0999 - accuracy: 0.8698 - val_loss: 0.1091 - val_accuracy: 0.8556
# Epoch 59/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0997 - accuracy: 0.8685 - val_loss: 0.1117 - val_accuracy: 0.8501
# Epoch 60/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0982 - accuracy: 0.8720 - val_loss: 0.1080 - val_accuracy: 0.8565
# Epoch 61/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0975 - accuracy: 0.8728 - val_loss: 0.1102 - val_accuracy: 0.8548
# Epoch 62/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.1001 - accuracy: 0.8680 - val_loss: 0.1090 - val_accuracy: 0.8545
# Epoch 63/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0980 - accuracy: 0.8717 - val_loss: 0.1099 - val_accuracy: 0.8529
# Epoch 64/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0966 - accuracy: 0.8740 - val_loss: 0.1106 - val_accuracy: 0.8535
# Epoch 65/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0979 - accuracy: 0.8720 - val_loss: 0.1097 - val_accuracy: 0.8534
# Epoch 66/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0973 - accuracy: 0.8724 - val_loss: 0.1082 - val_accuracy: 0.8577
# Epoch 67/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0976 - accuracy: 0.8723 - val_loss: 0.1086 - val_accuracy: 0.8558
# Epoch 68/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0972 - accuracy: 0.8730 - val_loss: 0.1095 - val_accuracy: 0.8546
# Epoch 69/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0977 - accuracy: 0.8721 - val_loss: 0.1088 - val_accuracy: 0.8566
# Epoch 70/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0953 - accuracy: 0.8752 - val_loss: 0.1096 - val_accuracy: 0.8547
# Epoch 71/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0976 - accuracy: 0.8734 - val_loss: 0.1088 - val_accuracy: 0.8547
# Epoch 72/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0974 - accuracy: 0.8719 - val_loss: 0.1107 - val_accuracy: 0.8552
# Epoch 73/115
# 5940/5940 [==============================] - 14s 2ms/step - loss: 0.0986 - accuracy: 0.8708 - val_loss: 0.1107 - val_accuracy: 0.8531
# Epoch 00073: early stopping
# Test loss: 0.11070911586284637
# Test accuracy: 0.8531312942504883
# 465/465 [==============================] - 1s 2ms/step - loss: 0.1069 - accuracy: 0.8568
# loss on test set :  0.10689517855644226
# accuracy on test set :  0.8568350076675415
#
# Best epoch for the val_loss is :  22
#
# Best epoch for the val_acc is :  24
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85      7425
#            1       0.82      0.90      0.86      7425
#
#     accuracy                           0.85     14850
#    macro avg       0.86      0.85      0.85     14850
# weighted avg       0.86      0.85      0.85     14850

# %%
model.save('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model4')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model4/assets

# %%
model = tf.keras.models.load_model('/content/drive/Shareddrives/ReseauNeurones/resume_resultats/models/troncons_train_aA_test_aA_model4')

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')
# Out:
# (-0.5, 1.5, 1.5, -0.5)

# %%
testLocuteur(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_loc_entrainement4.csv", "drive/Shareddrives/ReseauNeurones/images_troncons/test/*/*")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
testSegment(model, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_seg_entrainement4.csv", "/content/drive/Shareddrives/ReseauNeurones/images_troncons/test/*/*")
# Out:
# ['A', 'a']
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
Y_test = np.argmax(y_test_troncons1, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons1)
resultat["1"] = getScoreLocuteur(classification_report(Y_test, y_pred))

# 2
Y_test = np.argmax(y_test_troncons2, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons2)
resultat["2"] = getScoreLocuteur(classification_report(Y_test, y_pred))

# 3
Y_test = np.argmax(y_test_troncons3, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test_troncons3)
resultat["3"] = getScoreLocuteur(classification_report(Y_test, y_pred))

getCSV(resultat, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_tier_entrainement4.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
proba = model.predict(x_test)
print(proba)
# Out:
# [[0.0546244  0.9453756 ]
#  [0.1496605  0.85033953]
#  [0.07202277 0.92797726]
#  ...
#  [0.9706789  0.02932115]
#  [0.3917159  0.6082841 ]
#  [0.97271866 0.02728137]]

# %%
print(proba[0])
for i in proba[0]:
  print(f"{i:.6f}")
# Out:
# [0.0546244 0.9453756]
# 0.054624
# 0.945376

# %%
resultat = dict()

for i in range(len(proba)):
  score = dict()
  score["son"] = fileNames[i].split('_')[6]
  score["tier"] = fileNames[i].split('_')[-1][0]
  score["contexte_gauche"] = fileNames[i].split('_')[8]
  score["contexte_droit"] = fileNames[i].split('_')[9]
  score["contextes"] = fileNames[i].split('_')[8] + "_" + fileNames[i].split('_')[9]
  score["temps_debut"] = fileNames[i].split('_')[-3]
  score["temps_fin"] = fileNames[i].split('_')[-2]
  score["proba_oral"] = f"{proba[i][0]:.6f}"
  score["proba_nasal"] = f"{proba[i][1]:.6f}"
  resultat[i+1] = score


getCSV(resultat, "/content/drive/Shareddrives/ReseauNeurones/resume_resultats/troncons/aA/all_score_context_entrainement4.csv")

# %%
resultat = dict()

# %% [markdown]
# ##Entraînement 1
#     activation : tanh
#     model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(5,5),
                 activation='tanh',
                 input_shape=(img_rows, img_cols, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (5, 5), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
model.summary()
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

# model.compile(loss=keras.losses.categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test), 
          callbacks=[es,mc])

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

best_model=keras.models.load_model('best_model.h5')
test_loss, test_acc = best_model.evaluate(x_test, y_test)
val_loss_list=history.history['val_loss']
best_val_loss_epoch=val_loss_list.index(min(val_loss_list))
val_acc_list = history.history["val_accuracy"]
best_val_acc_epoch = val_acc_list.index(max(val_acc_list))

print("loss on test set : ", test_loss)
print("accuracy on test set : ", test_acc)
print("\nBest epoch for the val_loss is : ", best_val_loss_epoch)
print("\nBest epoch for the val_acc is : ", best_val_acc_epoch)

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report
import numpy as np

Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test)
print(classification_report(Y_test, y_pred))

# %% [markdown]
# ##Entraînement 2
#     activation : relu
#     model.compile(loss=keras.losses.categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(5,5),
                 activation='relu',
                 input_shape=(img_rows, img_cols, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (5, 5), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
model.summary()
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

# model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test), 
          callbacks=[es,mc])

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

best_model=keras.models.load_model('best_model.h5')
test_loss, test_acc = best_model.evaluate(x_test, y_test)
val_loss_list=history.history['val_loss']
best_val_loss_epoch=val_loss_list.index(min(val_loss_list))
val_acc_list = history.history["val_accuracy"]
best_val_acc_epoch = val_acc_list.index(max(val_acc_list))

print("loss on test set : ", test_loss)
print("accuracy on test set : ", test_acc)
print("\nBest epoch for the val_loss is : ", best_val_loss_epoch)
print("\nBest epoch for the val_acc is : ", best_val_acc_epoch)

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test)
print(classification_report(Y_test, y_pred))

# %% [markdown]
# ##Entraînement 3
#     activation : tanh
#     model.compile(loss=keras.losses.categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(5,5),
                 activation='tanh',
                 input_shape=(img_rows, img_cols, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (5, 5), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
model.summary()
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

# model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test), 
          callbacks=[es,mc])

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

best_model=keras.models.load_model('best_model.h5')
test_loss, test_acc = best_model.evaluate(x_test, y_test)
val_loss_list=history.history['val_loss']
best_val_loss_epoch=val_loss_list.index(min(val_loss_list))
val_acc_list = history.history["val_accuracy"]
best_val_acc_epoch = val_acc_list.index(max(val_acc_list))

print("loss on test set : ", test_loss)
print("accuracy on test set : ", test_acc)
print("\nBest epoch for the val_loss is : ", best_val_loss_epoch)
print("\nBest epoch for the val_acc is : ", best_val_acc_epoch)

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test)
print(classification_report(Y_test, y_pred))

# %% [markdown]
# ##Entraînement 4
#     activation : relu
#     model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(5,5),
                 activation='relu',
                 input_shape=(img_rows, img_cols, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (5, 5), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
model.summary()
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

# model.compile(loss=keras.losses.categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test), 
          callbacks=[es,mc])

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

best_model=keras.models.load_model('best_model.h5')
test_loss, test_acc = best_model.evaluate(x_test, y_test)
val_loss_list=history.history['val_loss']
best_val_loss_epoch=val_loss_list.index(min(val_loss_list))
val_acc_list = history.history["val_accuracy"]
best_val_acc_epoch = val_acc_list.index(max(val_acc_list))

print("loss on test set : ", test_loss)
print("accuracy on test set : ", test_acc)
print("\nBest epoch for the val_loss is : ", best_val_loss_epoch)
print("\nBest epoch for the val_acc is : ", best_val_acc_epoch)

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test)
print(classification_report(Y_test, y_pred))

# %% [markdown]
# ---
#
# ---
#
#
#
#
#
# Et quelques autres entraînements pour essayer de voir d'où vient la différence au niveau de la progression dans un entraînement...
#
#
# ---
#
# ---

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(5,5),
                 activation='relu',
                 input_shape=(img_rows, img_cols, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (5, 5), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
model.summary()
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

# model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

model.compile(loss='mean_squared_error',
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test), 
          callbacks=[es,mc])

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

best_model=keras.models.load_model('best_model.h5')
test_loss, test_acc = best_model.evaluate(x_test, y_test)
val_loss_list=history.history['val_loss']
best_val_loss_epoch=val_loss_list.index(min(val_loss_list))
val_acc_list = history.history["val_accuracy"]
best_val_acc_epoch = val_acc_list.index(max(val_acc_list))

print("loss on test set : ", test_loss)
print("accuracy on test set : ", test_acc)
print("\nBest epoch for the val_loss is : ", best_val_loss_epoch)
print("\nBest epoch for the val_acc is : ", best_val_acc_epoch)

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test)
print(classification_report(Y_test, y_pred))

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(5,5),
                 activation='relu',
                 input_shape=(img_rows, img_cols, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (5, 5), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
model.summary()
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

# model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=sgd,
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test), 
          callbacks=[es,mc])

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

best_model=keras.models.load_model('best_model.h5')
test_loss, test_acc = best_model.evaluate(x_test, y_test)
val_loss_list=history.history['val_loss']
best_val_loss_epoch=val_loss_list.index(min(val_loss_list))
val_acc_list = history.history["val_accuracy"]
best_val_acc_epoch = val_acc_list.index(max(val_acc_list))

print("loss on test set : ", test_loss)
print("accuracy on test set : ", test_acc)
print("\nBest epoch for the val_loss is : ", best_val_loss_epoch)
print("\nBest epoch for the val_acc is : ", best_val_acc_epoch)

# %%
predictions = model.predict(np.array(x_test), batch_size=100)
ConfusionMatrix(np.array(y_test.argmax(axis=1)), predictions.argmax(axis=1)).plot().axis('on')

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(x_test)
print(classification_report(Y_test, y_pred))
